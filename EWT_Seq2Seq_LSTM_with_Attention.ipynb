# %% [markdown]
# <a href="https://colab.research.google.com/github/SFStefenon/EWT-Seq2Seq-LSTM-Attention/blob/main/EWT_Seq2Seq_LSTM_with_Attention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Optimized EWT-Seq2Seq-LSTM with Attention Mechanism

# %% [markdown]
# Wrote by Dr. **Laio Oriel Seman** and Dr. **Stefano Frizzo Stefenon**.
#
# Trento, Italy, March 03, 2023.

# %% [markdown]
# The proposed analysis is divided according to the models evaluated:
#
# > **Seq2Seq-LSTM with Attention**: Evaluation of the starting model using the Attention Mechanism.
#
# > **Optimized Seq2Seq-LSTM with Attention**: Evaluation of the model with the optimized hyperparameters (based on Optuna).
#
# > **Standard Seq2Seq LSTM**: Standard model for comparative purposes.

# %% [markdown]
# The definition of the number of epochs and the number of experiments results in a significant variation in simulation time.

# %%
# Number of epochs
# Recommended at least 100
epc = 100

# Number of experiments to perform a statistical analysis
# Recommended at least 50
statistics = 5

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import time

from keras.models import Sequential, Model, load_model
from keras.layers import LSTM, Dense, RepeatVector, TimeDistributed, Input, BatchNormalization, multiply, concatenate, Flatten, Activation, dot
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import EarlyStopping

# !pip install -q ewtpy
import ewtpy
# !pip install -q optuna
import optuna
# !pip install -q phik
import phik
from phik import resources, report

# %% [markdown]
# # Load the Dataset

# %%
# Load the dataset
mydata=np.loadtxt('Data.csv', delimiter=",", dtype=np.float32, skiprows=1)

insu1=mydata[:,[0]]
insu2=mydata[:,[1]] 
insu3=mydata[:,[2]] 
insu4=mydata[:,[3]] 
insu5=mydata[:,[4]] 
insu6=mydata[:,[5]]

# %% [markdown]
# Definition of the insulators based on the correlation of the time series.

# %%
# Preparing the dataset
x1 = insu1[::100].flatten()
x2 = insu2[::100].flatten()
x3 = insu3[::100].flatten()
x4 = insu4[::100].flatten()
x5 = insu5[::100].flatten()
x6 = insu6[::100].flatten()

# Creating the dataframe
dfphi = pd.DataFrame({'Insulator 1': x1, 'Insulator 2': x2, 'Insulator 3': x3, 'Insulator 4': x4, 'Insulator 5': x5, 'Insulator 6': x6})

# Generating the report
report.correlation_report(dfphi, pdf_file_name='report.pdf')
# Out:
# interval columns not set, guessing: ['Insulator 1', 'Insulator 2', 'Insulator 3', 'Insulator 4', 'Insulator 5', 'Insulator 6']
# (             Insulator 1  Insulator 2  Insulator 3  Insulator 4  Insulator 5  \
#  Insulator 1     1.000000     0.879660     0.878725     0.790104     0.767424
#  Insulator 2     0.879660     1.000000     0.948951     0.813480     0.624732
#  Insulator 3     0.878725     0.948951     1.000000     0.819363     0.645664
#  Insulator 4     0.790104     0.813480     0.819363     1.000000     0.634544
#  Insulator 5     0.767424     0.624732     0.645664     0.634544     1.000000
#  Insulator 6     0.831765     0.743904     0.716502     0.610388     0.529213
#
#               Insulator 6
#  Insulator 1     0.831765
#  Insulator 2     0.743904
#  Insulator 3     0.716502
#  Insulator 4     0.610388
#  Insulator 5     0.529213
#  Insulator 6     1.000000  , array([[0.95570846],
#         [0.9564916 ],
#         [0.95584499],
#         [0.84158577],
#         [0.80078363],
#         [0.85384052]]),              Insulator 1  Insulator 2  Insulator 3  Insulator 4  Insulator 5  \
#  Insulator 1    51.035664    38.561630    38.275836    39.928851    35.780628
#  Insulator 2    38.561630    53.040786    42.477244    39.952664    29.715951
#  Insulator 3    38.275836    42.477244    55.875174    41.685425    30.721492
#  Insulator 4    39.928851    39.952664    41.685425    50.749136    29.970058
#  Insulator 5    35.780628    29.715951    30.721492    29.970058    41.954120
#  Insulator 6    31.162154    26.198740    25.146049    26.867319    23.009556
#
#               Insulator 6
#  Insulator 1    31.162154
#  Insulator 2    26.198740
#  Insulator 3    25.146049
#  Insulator 4    26.867319
#  Insulator 5    23.009556
#  Insulator 6    35.965207  , {'Insulator_1:Insulator_2':             0.0_0.1   0.1_0.1    0.1_0.1   0.1_0.1    0.1_0.2    0.2_0.2  \
#   -0.0_0.0  -8.570627 -5.238662 -21.191846  9.305933  17.587185  10.918647
#   0.0_0.1    7.871538 -0.575662  -4.257075 -1.171201  -1.491878  -0.840908
#   0.1_0.1   15.994368  9.600445  -8.209536 -3.960117  -4.797767  -3.063202
#   0.1_0.1    5.646815  5.831116  -5.278617 -1.540463  -1.936063  -1.126865
#   0.1_0.1   -0.729034 -0.333738   1.885787 -0.722079  -0.941993  -0.502717
#   0.1_0.2   -9.337405 -5.735561  35.426607 -9.279873 -11.042573  -7.378860
#   0.2_0.2   -1.503631 -0.758507   4.319334 -1.491198  -1.877072  -1.088412
#   0.2_0.2   -1.062517 -0.510151  -0.777280  4.276526  -1.348544  -0.750738
#   0.2_0.2   -2.390642 -1.289975   3.207828  3.014044  -2.925380  -1.785543
#   0.2_0.3   -2.353924 -1.267413   6.783509 -2.336219  -2.882187  -1.756396
#
#              0.2_0.2   0.2_0.2   0.2_0.2   0.2_0.3
#   -0.0_0.0  7.638671  8.639399  5.833421  1.363813
#   0.0_0.1  -0.520701 -0.615831 -0.360023 -0.074794
#   0.1_0.1  -2.124631 -2.414406 -1.601235 -0.441250
#   0.1_0.1  -0.715688 -0.839271 -0.503243 -0.109210
#   0.1_0.1  -0.299714 -0.358836 -0.202514 -0.039700
#   0.1_0.2  -5.372656 -5.994798 -4.236790 -1.504140
#   0.2_0.2  -0.689117 -0.808968 -0.483525 -0.104333
#   0.2_0.2  -0.460627 -0.546424 -0.316650 -0.064838
#   0.2_0.2  -1.183066 -1.367028 -0.858184 -0.204205
#   0.2_0.3  -1.162000 -1.343408 -0.841911 -0.199563  ,
#   'Insulator_1:Insulator_3':             0.0_0.1    0.1_0.1    0.1_0.1   0.1_0.1    0.1_0.2    0.2_0.2  \
#   -0.0_0.0  -9.339502 -10.152423 -10.784457 -8.209536  24.660589  15.469333
#   0.0_0.1    7.537485  -1.491878  -1.618407 -2.915606  -2.077972  -1.292010
#   0.1_0.1   16.605372   4.784266  -5.122975 -8.381174  -6.289132  -4.278435
#   0.1_0.1    9.598802  -1.936063  -2.091087 -3.663958  -2.650877  -1.690031
#   0.1_0.1   -0.831044   4.720250  -1.030189 -1.960912  -1.355478  -0.804247
#   0.1_0.2  -10.166828   7.480559  17.473097  6.870257 -14.126825  -9.951407
#   0.2_0.2   -1.684135  -1.877072  -2.028392  6.209913  -2.575121  -1.637035
#   0.2_0.2   -1.200245  -1.348544  -1.465498  4.489374  -1.891500  -1.164204
#   0.2_0.2   -2.649906  -2.925380  -3.140522  9.591538  -3.913443  -2.582416
#   0.2_0.3   -2.610031  -2.882187  -3.094755  9.450362  -3.858515  -2.543360
#
#              0.2_0.2   0.2_0.2   0.2_0.3   0.3_0.3
#   -0.0_0.0  4.643324  3.437219  1.363813  0.845890
#   0.0_0.1  -0.265328 -0.181757 -0.074794 -0.056156
#   0.1_0.1  -1.262306 -0.932985 -0.441250 -0.342761
#   0.1_0.1  -0.375278 -0.260187 -0.109210 -0.082407
#   0.1_0.1  -0.146975 -0.099149 -0.039700 -0.029556
#   0.1_0.2  -3.485620 -2.732023 -1.504140 -1.226713
#   0.2_0.2  -0.360023 -0.249215 -0.104333 -0.078678
#   0.2_0.2  -0.232449 -0.158609 -0.064838 -0.048593
#   0.2_0.2  -0.655162 -0.465913 -0.204205 -0.155650
#   0.2_0.3  -0.642142 -0.456175 -0.199563 -0.152045  ,
#   'Insulator_1:Insulator_4':            -0.0_0.0   0.0_0.0    0.0_0.1   0.1_0.1   0.1_0.1    0.1_0.1  \
#   -0.0_0.0  40.620843 -5.399423  -7.014219 -7.504362 -5.784015 -20.173062
#   0.0_0.1   -2.880258  4.588228   5.148798 -0.978640 -0.668096  -3.775239
#   0.1_0.1   -8.293500  5.471675  13.800150  8.854934 -2.569051 -10.494607
#   0.1_0.1   -3.621314  9.084873   3.215191 -1.300316 -0.906601  -4.699395
#   0.1_0.1   -1.935154 -0.350509  -0.533302  5.522798 -0.391769  -2.590665
#   0.1_0.2  -18.009122 -5.909515  -7.656574  0.236057  8.484121  23.283106
#   0.2_0.2   -3.523549 -0.792291  -1.146011 -1.257225 -0.874329   4.954810
#   0.2_0.2   -2.637878 -0.534413  -0.793477 -0.876506 -0.593714   3.493080
#   0.2_0.2   -5.245895 -1.341622  -1.870448 -2.033382 -1.466070   7.651838
#   0.2_0.3   -5.175328 -1.318349  -1.840215 -2.001090 -1.441111   7.668907
#
#              0.1_0.1   0.2_0.2   0.2_0.2
#   -0.0_0.0  8.345135  0.190667  1.363813
#   0.0_0.1  -0.602537 -0.037265 -0.074794
#   0.1_0.1  -2.374597 -0.237242 -0.441250
#   0.1_0.1  -0.822085 -0.055069 -0.109210
#   0.1_0.1  -0.350509 -0.019341 -0.039700
#   0.1_0.2  -5.909515 -0.906309 -1.504140
#   0.2_0.2  -0.792291 -0.052532 -0.104333
#   0.2_0.2  -0.534413 -0.032156 -0.064838
#   0.2_0.2  -0.388611 -0.105327 -0.204205
#   0.2_0.3  -1.318349 -0.102834 -0.199563  ,
#   'Insulator_1:Insulator_5':            -0.0_0.0   0.0_0.0    0.0_0.1   0.1_0.1   0.1_0.1   0.1_0.1  \
#   -0.0_0.0  40.880142 -1.771220 -21.048318 -8.517326 -1.771220 -1.564953
#   0.0_0.1   -3.513185  6.243874   0.968629 -1.171201 -0.111341 -0.093186
#   0.1_0.1   -9.854776 -0.621387  11.941878 -3.960117 -0.621387 -0.533837
#   0.1_0.1   -4.384039 -0.161318   4.613831 -1.540463 -0.161318 -0.135506
#   0.1_0.1   -2.398125 -0.059781   1.980716 -0.722079 -0.059781 -0.049775
#   0.1_0.2  -20.473761 -1.976654  26.322731  0.184033 -0.996499 -0.711885
#   0.2_0.2   -4.269237 -0.154270  -5.011365  9.449036  1.623283 -0.129523
#   0.2_0.2    1.148362 -0.096778  -3.816640  2.999840 -0.096778 -0.080898
#   0.2_0.2    0.140652 -0.296618  -7.325113  8.076027  1.230954 -0.251149
#   0.2_0.3    3.525891 -0.290089  -7.230514  0.272434  2.403301  3.671112
#
#              0.1_0.1   0.2_0.2
#   -0.0_0.0 -1.338797 -0.796487
#   0.0_0.1  -0.074794 -0.037265
#   0.1_0.1  -0.441250 -0.237242
#   0.1_0.1  -0.109210 -0.055069
#   0.1_0.1  -0.039700 -0.019341
#   0.1_0.2  -1.504140 -0.906309
#   0.2_0.2  -0.104333 -0.052532
#   0.2_0.2  -0.064838 -0.032156
#   0.2_0.2  -0.204205 -0.105327
#   0.2_0.3   3.684956  1.729643  ,
#   'Insulator_1:Insulator_6':            -0.0_0.1    0.1_0.2   0.2_0.2   0.3_0.4   0.7_0.8
#   -0.0_0.0  25.560273 -19.497489 -1.338797 -0.796487 -0.796487
#   0.0_0.1    2.772544  -3.568307 -0.074794 -0.037265 -0.037265
#   0.1_0.1   10.133595  -9.989751 -0.441250 -0.237242 -0.237242
#   0.1_0.1    3.777259  -4.450392 -0.109210 -0.055069 -0.055069
#   0.1_0.1    1.441246  -2.438591 -0.039700 -0.019341 -0.019341
#   0.1_0.2   -8.209536  40.722867 -1.504140 -0.906309 -0.906309
#   0.2_0.2   -5.784180   5.241251 -0.104333 -0.052532 -0.052532
#   0.2_0.2   -0.214975  -0.043151 -0.064838 -0.032156 -0.032156
#   0.2_0.2    1.508340  -3.336479  3.664418  1.717332  1.717332
#   0.2_0.3    5.855331  -6.296652 -0.199563 -0.102834 -0.102834,
#   'Insulator_2:Insulator_3':            0.0_0.1   0.1_0.1    0.1_0.1    0.1_0.1    0.1_0.2    0.2_0.2  \
#   0.0_0.1  26.323951 -4.558918  -4.870169  -7.991574  -5.986396  -4.061913
#   0.1_0.1   5.056427  6.538775  -2.857416  -4.863306  -3.573537  -2.340966
#   0.1_0.1 -12.095756  7.997044  14.428288  17.632014 -16.580410 -11.846088
#   0.1_0.1  -4.131585 -4.528396  -4.837862   2.888983   7.827507  -4.034246
#   0.1_0.2  -4.999676 -5.466831  -5.831080  -9.476068  23.081980  -3.310387
#   0.2_0.2  -3.201833 -3.522850  -3.773349  -6.288222   4.441890   9.023828
#   0.2_0.2  -2.228089 -2.468160  -2.655879  -4.548852  -3.331329  10.576698
#   0.2_0.2  -2.528880 -2.794265  -3.001585  -5.087980  -3.746672  13.697300
#   0.2_0.2  -1.684135 -1.877072  -2.028392  -3.565237  -2.575121  -1.637035
#   0.2_0.3  -0.470339 -0.539728  -0.595666  -1.215504  -0.807007  -0.453756
#
#             0.2_0.2   0.2_0.2   0.2_0.3   0.3_0.3
#   0.0_0.1 -1.181479 -0.869618 -0.407603 -0.315868
#   0.1_0.1 -0.575662 -0.406690 -0.176192 -0.133936
#   0.1_0.1 -4.257075 -3.365599 -1.902773 -1.567780
#   0.1_0.1 -1.171201 -0.861582 -0.403366 -0.312489
#   0.1_0.2 -1.491878 -1.114384 -0.539728 -0.422019
#   0.2_0.2 -0.840908 -0.606315 -0.272604 -0.209046
#   0.2_0.2  3.385925 -0.366092 -0.157293 -0.119340
#   0.2_0.2  0.598690 -0.436542 -0.190248 -0.144819
#   0.2_0.2  6.130461  7.754939  4.243704  3.276234
#   0.2_0.3  3.473767  2.209364 -0.019324 -0.014192  ,
#   'Insulator_2:Insulator_4':           -0.0_0.0    0.0_0.0    0.0_0.1   0.1_0.1   0.1_0.1    0.1_0.1  \
#   0.0_0.1  -7.905690  12.990227  15.785999 -1.429163 -2.426955 -10.016312
#   0.1_0.1  -4.809105   1.303908   4.238324  9.046774 -1.312323  -6.177542
#   0.1_0.1 -20.414570  -7.115606  -9.167791  2.040712  6.994001  35.593195
#   0.1_0.1   0.627759  -2.224164  -3.002376 -3.239599 -2.408814  -5.134264
#   0.1_0.2  18.910644  -2.749498  -3.669137 -3.948881 -2.968086 -11.827296
#   0.2_0.2  11.674733  -1.667023  -2.290540 -2.481563 -1.814386  -7.928368
#   0.2_0.2   8.178187  -1.097585  -1.551755 -1.692631 -1.203938  -5.790234
#   0.2_0.2   9.241812  -1.271105  -1.778747 -1.935417 -1.390420  -6.454171
#   0.2_0.2   6.265669  -0.792291  -1.146011 -1.257225 -0.874329  -4.577592
#   0.2_0.3   1.562050  -0.185573  -0.290478 -0.325800 -0.208836  -1.652916
#
#              0.1_0.1   0.2_0.2   0.2_0.2
#   0.0_0.1  -2.241191 -0.217997 -0.407603
#   0.1_0.1  -1.198379 -0.090340 -0.176192
#   0.1_0.1  -7.115606 -1.176306 -1.902773
#   0.1_0.1  14.314641  1.311506  3.008256
#   0.1_0.2  -2.749498 -0.294468 -0.539728
#   0.2_0.2  -1.667023 -0.142479 -0.272604
#   0.2_0.2  -1.097585 -0.080307 -0.157293
#   0.2_0.2  -1.271105 -0.097843 -0.190248
#   0.2_0.2  -0.792291 -0.052532 -0.104333
#   0.2_0.3  -0.185573 -0.009044 -0.019324  ,
#   'Insulator_2:Insulator_5':           -0.0_0.0   0.0_0.0    0.0_0.1    0.1_0.1   0.1_0.1   0.1_0.1  \
#   0.0_0.1  -9.402219  4.195024   9.750728  -3.757314 -0.576180 -0.494132
#   0.1_0.1  -5.777662 -0.257091   6.424303  -2.147163 -0.257091 -0.217213
#   0.1_0.1  -8.209536 -2.468315  17.908654  10.911825  1.329336  1.006452
#   0.1_0.1  13.069159 -0.570469 -10.807195  -3.731401 -0.570469 -0.489123
#   0.1_0.2  16.103319 -0.752364 -12.810481  -4.528396 -0.752364 -0.649399
#   0.2_0.2  10.035960 -0.391985  -8.629647  -2.878392 -0.391985 -0.333490
#   0.2_0.2   7.000658 -0.230255  -6.321136  -1.986965 -0.230255 -0.194241
#   0.2_0.2   7.929585 -0.276960  -7.037792  -2.261958 -0.276960 -0.234257
#   0.2_0.2   5.319072 -0.154270  -5.011365  -1.491198 -0.154270 -0.129523
#   0.2_0.3   1.122863 -0.029543  -1.843996  -0.403366 -0.029543 -0.024441
#
#             0.1_0.1   0.2_0.2
#   0.0_0.1 -0.407603 -0.217997
#   0.1_0.1 -0.176192 -0.090340
#   0.1_0.1  0.638655 -0.349326
#   0.1_0.1 -0.403366 -0.215585
#   0.1_0.2 -0.539728 -0.294468
#   0.2_0.2 -0.272604 -0.142479
#   0.2_0.2 -0.157293 -0.080307
#   0.2_0.2 -0.190248 -0.097843
#   0.2_0.2 -0.104333 -0.052532
#   0.2_0.3 -0.019324 -0.009044  ,
#   'Insulator_2:Insulator_6':           -0.0_0.1    0.1_0.2   0.2_0.2   0.3_0.4   0.7_0.8
#   0.0_0.1   9.584661  -9.531714 -0.407603 -0.217997 -0.217997
#   0.1_0.1   5.365827  -5.861832 -0.176192 -0.090340 -0.090340
#   0.1_0.1        NaN  36.998021  0.638655 -0.349326 -0.349326
#   0.1_0.1   9.514933  -9.473123 -0.403366 -0.215585 -0.215585
#   0.1_0.2  11.706305 -11.267552 -0.539728 -0.294468 -0.294468
#   0.2_0.2   7.261294  -7.536148 -0.272604 -0.142479 -0.142479
#   0.2_0.2   4.950012  -5.491943 -0.157293 -0.080307 -0.080307
#   0.2_0.2   5.663137  -6.126048 -0.190248 -0.097843 -0.097843
#   0.2_0.2   3.645719  -4.334115 -0.104333 -0.052532 -0.052532
#   0.2_0.3   0.300114  -1.546492 -0.019324 -0.009044 -0.009044,
#   'Insulator_3:Insulator_4':           -0.0_0.0    0.0_0.0    0.0_0.1    0.1_0.1   0.1_0.1    0.1_0.1  \
#   0.0_0.1  -8.621119  13.568617  18.825857  -0.895161 -2.689335 -10.897976
#   0.1_0.1  -9.378184  -2.749498  -3.669137  17.422756  8.658483  -4.877950
#   0.1_0.1  -9.967360  -2.954141  -3.928245  -4.224416  1.378160  13.708898
#   0.1_0.1 -15.728172  -5.014064  -6.528765  -6.988464 -2.959345  23.922125
#   0.1_0.2  21.764567  -3.689705  -4.858014  -5.212899 -3.967741 -15.078476
#   0.2_0.2  16.588535  -2.423418  -3.255615  -3.509043 -2.621038 -10.669112
#   0.2_0.2   5.008932  -0.602537  -0.887773  -0.978640 -0.668096  -3.775239
#   0.2_0.2   3.738502  -0.426646  -0.642137  -0.711996 -0.475600  -2.969650
#   0.2_0.3   1.562050  -0.185573  -0.290478  -0.325800 -0.208836  -1.652916
#   0.3_0.3   1.019676  -0.141197  -0.223084  -0.250923 -0.159248  -1.353656
#
#             0.1_0.1   0.2_0.2   0.2_0.2
#   0.0_0.1 -2.487568 -0.254009 -0.470339
#   0.1_0.1 -2.749498 -0.294468 -0.539728
#   0.1_0.1 -2.954141 -0.327537 -0.595666
#   0.1_0.1  3.578391  0.315479 -1.215504
#   0.1_0.2  2.989421 -0.455776  2.173325
#   0.2_0.2 -2.423418 -0.244436 -0.453756
#   0.2_0.2 -0.602537 -0.037265 -0.074794
#   0.2_0.2 -0.426646 -0.024475 -0.049799
#   0.2_0.3 -0.185573 -0.009044 -0.019324
#   0.3_0.3 -0.141197 -0.006463 -0.014192  ,
#   'Insulator_3:Insulator_5':           -0.0_0.0   0.0_0.0    0.0_0.1    0.1_0.1   0.1_0.1   0.1_0.1  \
#   0.0_0.1 -10.236693  4.000010  10.993273  -4.131585 -0.660274 -0.568069
#   0.1_0.1 -11.117648 -0.752364  13.684520  -4.528396 -0.752364  0.634427
#   0.1_0.1 -11.801386 -0.825978  14.728160  -4.232453 -0.825978 -0.714658
#   0.1_0.1  -6.622857 -1.617239  -2.441639  14.965348  2.397469  1.532238
#   0.1_0.2  22.295164 -1.100024 -16.240189  -5.947706 -1.100024 -0.959170
#   0.2_0.2  14.194756 -0.638127 -11.572682  -4.034246 -0.638127 -0.548564
#   0.2_0.2   4.206455 -0.111341  -4.144170  -1.171201 -0.111341 -0.093186
#   0.2_0.2   3.075506 -0.074683  -3.272756  -0.861582 -0.074683 -0.062295
#   0.2_0.3   1.122863 -0.029543  -1.843996  -0.403366 -0.029543 -0.024441
#   0.3_0.3   0.633536 -0.021890  -1.517316  -0.312489 -0.021890 -0.018045
#
#             0.1_0.1   0.2_0.2
#   0.0_0.1 -0.470339 -0.254009
#   0.1_0.1 -0.539728 -0.294468
#   0.1_0.1 -0.595666 -0.327537
#   0.1_0.1  1.536698  0.315479
#   0.1_0.2 -0.807007 -0.455776
#   0.2_0.2 -0.453756 -0.244436
#   0.2_0.2 -0.074794 -0.037265
#   0.2_0.2 -0.049799 -0.024475
#   0.2_0.3 -0.019324 -0.009044
#   0.3_0.3 -0.014192 -0.006463  ,
#   'Insulator_3:Insulator_6':           -0.0_0.1    0.1_0.2   0.2_0.2   0.3_0.4   0.7_0.8
#   0.0_0.1  10.602465 -10.376243 -0.470339 -0.254009 -0.254009
#   0.1_0.1  -2.960245   3.038608 -0.539728 -0.294468 -0.294468
#   0.1_0.1 -15.315459  17.114267 -0.595666 -0.327537 -0.327537
#   0.1_0.1  -8.209536  11.337740  1.536698  0.315479  0.315479
#   0.1_0.2  15.935301 -14.401343 -0.807007 -0.455776 -0.455776
#   0.2_0.2  10.335737 -10.156929 -0.453756 -0.244436 -0.244436
#   0.2_0.2   2.772544  -3.568307 -0.074794 -0.037265 -0.037265
#   0.2_0.2   1.875530  -2.799834 -0.049799 -0.024475 -0.024475
#   0.2_0.3   0.300114  -1.546492 -0.019324 -0.009044 -0.009044
#   0.3_0.3  -0.100422  -1.262802 -0.014192 -0.006463 -0.006463,
#   'Insulator_4:Insulator_5':            -0.0_0.0   0.0_0.0    0.0_0.1    0.1_0.1   0.1_0.1   0.1_0.1  \
#   -0.0_0.0  34.141729 -1.595104 -20.146337  -7.855029 -1.595104 -1.405325
#   0.0_0.0   -5.952731  5.162063   4.749205  -2.224164 -0.270361 -0.228593
#   0.0_0.1   -7.711503 -0.416661   8.976319  -3.002376 -0.416661 -0.354894
#   0.1_0.1   -8.209536 -0.465150   9.696715  -3.239599 -0.465150 -0.397065
#   0.1_0.1   -6.371498 -0.303125   7.076136  -2.408814 -0.303125  1.343061
#   0.1_0.1   -8.209536 -2.160665   9.452223  12.269779  1.695443  0.944503
#   0.1_0.1    7.801734 -0.270361  -6.939589  -2.224164 -0.270361 -0.228593
#   0.2_0.2    0.014130 -0.014198  -1.136106  -0.215585 -0.014198 -0.011622
#   0.2_0.2    1.122863 -0.029543  -1.843996  -0.403366 -0.029543 -0.024441
#
#              0.1_0.1   0.2_0.2
#   -0.0_0.0 -1.197832 -0.704122
#   0.0_0.0  -0.185573 -0.095344
#   0.0_0.1  -0.290478 -0.152315
#   0.1_0.1  -0.325800 -0.171902
#   0.1_0.1  -0.208836 -0.107817
#   0.1_0.1   0.948890 -0.115152
#   0.1_0.1  -0.185573 -0.095344
#   0.2_0.2  -0.009044 -0.003880
#   0.2_0.2  -0.019324 -0.009044  ,
#   'Insulator_4:Insulator_6':            -0.0_0.1    0.1_0.2   0.2_0.2   0.3_0.4   0.7_0.8
#   -0.0_0.0  22.724638 -18.315441 -1.197832 -0.704122 -0.704122
#   0.0_0.0    5.565291  -6.039128 -0.185573 -0.095344 -0.095344
#   0.0_0.1    7.584743  -7.818891 -0.290478 -0.152315 -0.152315
#   0.1_0.1    5.185045  -5.100374 -0.325800 -0.171902 -0.171902
#   0.1_0.1   -7.991574   8.176164 -0.208836 -0.107817 -0.107817
#   0.1_0.1   -8.209536  29.282455  0.948890 -0.115152 -0.115152
#   0.1_0.1    5.565291  -6.039128 -0.185573 -0.095344 -0.095344
#   0.2_0.2   -0.609950  -0.934669 -0.009044 -0.003880 -0.003880
#   0.2_0.2    0.300114  -1.546492 -0.019324 -0.009044 -0.009044,
#   'Insulator_5:Insulator_6':            -0.0_0.1    0.1_0.2   0.2_0.2   0.3_0.4   0.7_0.8
#   -0.0_0.0  29.678149 -20.721698 -1.518246 -0.915746 -0.915746
#   0.0_0.0    0.933180  -2.029109 -0.029543 -0.014198 -0.014198
#   0.0_0.1   -8.209536  20.607327 -1.843996 -1.136106 -1.136106
#   0.1_0.1   -8.041400   7.207819  3.008256  1.311506  1.311506
#   0.1_0.1   -0.226894  -0.188699 -0.029543 -0.014198 -0.014198
#   0.1_0.1    0.295345  -0.764407 -0.024441 -0.011622 -0.011622
#   0.1_0.1    0.300114  -1.546492 -0.019324 -0.009044 -0.009044
#   0.2_0.2   -0.609950  -0.934669 -0.009044 -0.003880 -0.003880}, {'all': 'report.pdf'})

# %% [markdown]
# For this evaluation samples 2 and 3 had the best correlation.

# %%
# Definition of a limit (after that the flashover happens)
insu2_limit = insu2[:94000]
insu3_limit = insu3[:94000]

# Preprocessing (downsample)
x1 = insu2_limit[::100]
x2 = insu3_limit[::100]

# %%
plt.figure(figsize=(8, 4))
plt.plot(range(len(x1)), x1, 'r', zorder=2, label='Insulator 1')
plt.plot(range(len(x2)), x2, 'b', zorder=2, label='Insulator 2')
plt.legend(loc='lower right', fancybox=True, shadow=False, ncol=1)
plt.xlabel('Sample Index')
plt.ylabel('Leakage Current (A)')
plt.grid(linestyle = '--', linewidth = 0.5, zorder=0)
plt.show()
# plt.savefig('LeakageCurrent.pdf')

# %% [markdown]
# # Empirical Wavelet Transform (EWT)

# %%
f1 = x1.flatten()
f2 = x2.flatten()

ewt1, mfb1, boundaries1 = ewtpy.EWT1D(f1, N = 3)
ewt2, mfb2, boundaries2 = ewtpy.EWT1D(f2, N = 3)

plt.figure(figsize=(8, 8))
for i in range(ewt1.shape[1]):
    plt.subplot(ewt1.shape[1], 1, i+1)
    plt.plot(ewt1[:,i])
    plt.grid(linestyle = '--', linewidth = 0.5, zorder=0)
    # plt.savefig('EWT.pdf')

# %%
fig, ((ax1, ax2)) = plt.subplots(2, 1, figsize=(8, 8))

ax1.plot(x1.flatten() - ewt1[:,0], 'b', zorder=2, label='Insulator 1 - EWT #1')
ax1.plot(ewt1[:,1], 'g', zorder=2, label='Insulator 1 - EWT #2')
ax1.set_ylabel('Normalized Value')
ax1.set_xlabel('Sample Index')
ax1.axis([0, len(x1), -0.035, 0.045])
ax1.grid(linestyle = '--', linewidth = 0.5, zorder=0)
ax1.legend(loc='lower right', fancybox=True, shadow=False, ncol=1)

ax2.plot(x2.flatten() - ewt2[:,0], 'k', zorder=2, label='Insulator 2 - EWT #1')
ax2.plot(ewt2[:,1], 'r', zorder=2, label='Insulator 2 - EWT #2')
ax2.set_ylabel('Normalized Value')
ax2.set_xlabel('Sample Index')
ax2.axis([0, len(x1), -0.035, 0.045])
ax2.grid(linestyle = '--', linewidth = 0.5, zorder=0)
ax2.legend(loc='lower right', fancybox=True, shadow=False, ncol=1)
plt.show 
# plt.savefig('Normalized.pdf')
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Organize the data

# %%
# Definition of dataset setup for comparison
train_ratio = 0.7
batch_siz = 16

t = np.linspace(0, 50*np.pi, len(x1))
train_len = int(train_ratio * t.shape[0])
x_index = np.array(range(len(t)))

# %%
# Data normalization
x_lbl = np.column_stack([x1.flatten() - ewt1[:,0], ewt1[:,1], x2.flatten() - ewt2[:,0], ewt2[:,1], [1]*train_len+[0]*(len(x_index)-train_len)])
print(x_lbl.shape)

# Perform min-max normalization
x_normalize = x_lbl.copy()
# Out:
# (940, 5)

# %%
# Organized truncat, smaller train_len and smaller test_len, to decrease the steps
def truncate(x, feature_cols=range(3), target_cols=range(3), label_col=3, train_len=100, test_len=20):
    in_, out_, lbl = [], [], []
    for i in range(len(x)-train_len-test_len+1):
        in_.append(x[i:(i+train_len), feature_cols].tolist())
        out_.append(x[(i+train_len):(i+train_len+test_len), target_cols].tolist())
        lbl.append(x[i+train_len, label_col])
    return np.array(in_), np.array(out_), np.array(lbl)

X_in, X_out, lbl = truncate(x_normalize, feature_cols=range(4), target_cols=range(4), 
                            label_col=4, train_len=10, test_len=5)
print(X_in.shape, X_out.shape, lbl.shape)

X_input_train = X_in[np.where(lbl==1)]
X_output_train = X_out[np.where(lbl==1)]
X_input_test = X_in[np.where(lbl==0)]
X_output_test = X_out[np.where(lbl==0)]
# Out:
# (926, 10, 4) (926, 5, 4) (926,)

# %% [markdown]
# # Model Evaluation 1: Seq2Seq-LSTM with Attention

# %% [markdown]
# ## Model evaluation

# %%
# Initial number of hidden neurons
n_hidden = 100

input_train = Input(shape=(X_input_train.shape[1], X_input_train.shape[2]-1))
output_train = Input(shape=(X_output_train.shape[1], X_output_train.shape[2]-1))

encoder_stack_h, encoder_last_h, encoder_last_c = LSTM(n_hidden, activation='elu', dropout=0.2, recurrent_dropout=0.2, return_state=True, return_sequences=True)(input_train)
encoder_last_h = BatchNormalization(momentum=0.6)(encoder_last_h)
encoder_last_c = BatchNormalization(momentum=0.6)(encoder_last_c)

decoder_input = RepeatVector(output_train.shape[1])(encoder_last_h)
decoder_stack_h = LSTM(n_hidden, activation='elu', dropout=0.2, recurrent_dropout=0.2, return_state=False, return_sequences=True)(decoder_input, initial_state=[encoder_last_h, encoder_last_c])

attention = dot([decoder_stack_h, encoder_stack_h], axes=[2, 2])
attention = Activation('softmax')(attention)
context = dot([attention, encoder_stack_h], axes=[2,1])
context = BatchNormalization(momentum=0.6)(context)

decoder_combined_context = concatenate([context, decoder_stack_h])
out = TimeDistributed(Dense(output_train.shape[2]))(decoder_combined_context)

model = Model(inputs=input_train, outputs=out)
opt = Adam(lr=0.01, clipnorm=1)
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mse', 'mae', 'mape'])

# Evaluate the time for training the model
inicio = time.time()

# EWT considered
TOTAL = 3

es = EarlyStopping(monitor='val_loss', mode='min', patience=50)
history = model.fit(X_input_train[:, :, :TOTAL], X_output_train[:, :, :TOTAL], validation_split=0.2, epochs=epc, verbose=1, callbacks=[es], batch_size=batch_siz)

train_loss = history.history['loss']
valid_loss = history.history['val_loss']
mse = history.history['mse']
mae = history.history['mae']
mape = history.history['mape']
model.save('model_forecasting_seq2seq.h5')

train_pred_detrend = model.predict(X_input_train[:, :, :TOTAL])
test_pred_detrend = model.predict(X_input_test[:, :, :TOTAL])
train_true_detrend = X_output_train[:, :, :TOTAL]
test_true_detrend = X_output_test[:, :, :TOTAL]
data_final = dict()

fim = time.time()
time_s = fim - inicio

print('\nTime: {:.2f}'.format(time_s))
print('MSE: {0:.2e}'.format(mse[-1])) 
print('MAE: {0:.2e}'.format(mae[-1]))
print('MAPE: {0:.2e}'.format(mape[-1]))
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 33/33 [==============================] - 18s 231ms/step - loss: 6.9877e-05 - mse: 6.9877e-05 - mae: 0.0060 - mape: 651.2137 - val_loss: 2.5433e-05 - val_mse: 2.5433e-05 - val_mae: 0.0040 - val_mape: 563.8717
# Epoch 2/100
# 33/33 [==============================] - 5s 153ms/step - loss: 2.8374e-05 - mse: 2.8374e-05 - mae: 0.0038 - mape: 411.1325 - val_loss: 1.1318e-04 - val_mse: 1.1318e-04 - val_mae: 0.0099 - val_mape: 1336.9562
# Epoch 3/100
# 33/33 [==============================] - 6s 196ms/step - loss: 1.8644e-05 - mse: 1.8644e-05 - mae: 0.0030 - mape: 325.0027 - val_loss: 1.1403e-04 - val_mse: 1.1403e-04 - val_mae: 0.0088 - val_mape: 2169.8799
# Epoch 4/100
# 33/33 [==============================] - 5s 138ms/step - loss: 1.7136e-05 - mse: 1.7136e-05 - mae: 0.0028 - mape: 274.6412 - val_loss: 1.2647e-05 - val_mse: 1.2647e-05 - val_mae: 0.0027 - val_mape: 707.7227
# Epoch 5/100
# 33/33 [==============================] - 2s 73ms/step - loss: 1.9187e-05 - mse: 1.9187e-05 - mae: 0.0030 - mape: 298.6766 - val_loss: 8.7415e-05 - val_mse: 8.7415e-05 - val_mae: 0.0082 - val_mape: 1705.2122
# Epoch 6/100
# 33/33 [==============================] - 3s 83ms/step - loss: 1.5635e-05 - mse: 1.5635e-05 - mae: 0.0027 - mape: 267.6563 - val_loss: 2.5819e-05 - val_mse: 2.5819e-05 - val_mae: 0.0040 - val_mape: 675.5352
# Epoch 7/100
# 33/33 [==============================] - 3s 90ms/step - loss: 1.6501e-05 - mse: 1.6501e-05 - mae: 0.0029 - mape: 307.5464 - val_loss: 7.4734e-05 - val_mse: 7.4734e-05 - val_mae: 0.0077 - val_mape: 1791.2781
# Epoch 8/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.5443e-05 - mse: 1.5443e-05 - mae: 0.0028 - mape: 279.6338 - val_loss: 4.0777e-05 - val_mse: 4.0777e-05 - val_mae: 0.0054 - val_mape: 1209.4020
# Epoch 9/100
# 33/33 [==============================] - 2s 71ms/step - loss: 2.0998e-05 - mse: 2.0998e-05 - mae: 0.0032 - mape: 324.9489 - val_loss: 6.2515e-05 - val_mse: 6.2515e-05 - val_mae: 0.0073 - val_mape: 955.9650
# Epoch 10/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.7713e-05 - mse: 1.7713e-05 - mae: 0.0030 - mape: 311.7697 - val_loss: 2.7088e-05 - val_mse: 2.7088e-05 - val_mae: 0.0046 - val_mape: 706.5465
# Epoch 11/100
# 33/33 [==============================] - 3s 77ms/step - loss: 1.5569e-05 - mse: 1.5569e-05 - mae: 0.0028 - mape: 324.6802 - val_loss: 6.7668e-06 - val_mse: 6.7668e-06 - val_mae: 0.0018 - val_mape: 386.2664
# Epoch 12/100
# 33/33 [==============================] - 3s 97ms/step - loss: 1.4773e-05 - mse: 1.4773e-05 - mae: 0.0027 - mape: 297.1720 - val_loss: 4.6216e-05 - val_mse: 4.6216e-05 - val_mae: 0.0062 - val_mape: 1558.1621
# Epoch 13/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.5127e-05 - mse: 1.5127e-05 - mae: 0.0027 - mape: 277.4460 - val_loss: 1.8373e-05 - val_mse: 1.8373e-05 - val_mae: 0.0035 - val_mape: 529.9628
# Epoch 14/100
# 33/33 [==============================] - 2s 70ms/step - loss: 2.0727e-05 - mse: 2.0727e-05 - mae: 0.0034 - mape: 398.9352 - val_loss: 1.4121e-05 - val_mse: 1.4121e-05 - val_mae: 0.0029 - val_mape: 919.6586
# Epoch 15/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.6262e-05 - mse: 1.6262e-05 - mae: 0.0028 - mape: 279.3343 - val_loss: 2.0990e-05 - val_mse: 2.0990e-05 - val_mae: 0.0034 - val_mape: 726.9374
# Epoch 16/100
# 33/33 [==============================] - 2s 72ms/step - loss: 1.7613e-05 - mse: 1.7613e-05 - mae: 0.0030 - mape: 363.0642 - val_loss: 3.0215e-05 - val_mse: 3.0215e-05 - val_mae: 0.0049 - val_mape: 806.5991
# Epoch 17/100
# 33/33 [==============================] - 3s 102ms/step - loss: 1.6437e-05 - mse: 1.6437e-05 - mae: 0.0029 - mape: 338.1735 - val_loss: 2.4081e-05 - val_mse: 2.4081e-05 - val_mae: 0.0041 - val_mape: 1085.4456
# Epoch 18/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.2658e-05 - mse: 1.2658e-05 - mae: 0.0024 - mape: 256.0979 - val_loss: 2.0947e-05 - val_mse: 2.0947e-05 - val_mae: 0.0034 - val_mape: 361.4384
# Epoch 19/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.5869e-05 - mse: 1.5869e-05 - mae: 0.0029 - mape: 331.9188 - val_loss: 7.4257e-06 - val_mse: 7.4257e-06 - val_mae: 0.0018 - val_mape: 607.0846
# Epoch 20/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.2150e-05 - mse: 1.2150e-05 - mae: 0.0023 - mape: 244.5027 - val_loss: 5.4452e-05 - val_mse: 5.4452e-05 - val_mae: 0.0063 - val_mape: 1282.4069
# Epoch 21/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.3091e-05 - mse: 1.3091e-05 - mae: 0.0024 - mape: 254.8537 - val_loss: 2.1008e-05 - val_mse: 2.1008e-05 - val_mae: 0.0039 - val_mape: 1076.4613
# Epoch 22/100
# 33/33 [==============================] - 4s 108ms/step - loss: 1.1962e-05 - mse: 1.1962e-05 - mae: 0.0023 - mape: 218.5281 - val_loss: 7.9892e-06 - val_mse: 7.9892e-06 - val_mae: 0.0022 - val_mape: 334.0089
# Epoch 23/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.3601e-05 - mse: 1.3601e-05 - mae: 0.0026 - mape: 270.0990 - val_loss: 1.7311e-05 - val_mse: 1.7311e-05 - val_mae: 0.0034 - val_mape: 532.1159
# Epoch 24/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.4673e-05 - mse: 1.4673e-05 - mae: 0.0027 - mape: 287.7858 - val_loss: 3.0203e-05 - val_mse: 3.0203e-05 - val_mae: 0.0047 - val_mape: 1334.4182
# Epoch 25/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.6921e-05 - mse: 1.6921e-05 - mae: 0.0030 - mape: 346.1945 - val_loss: 2.5269e-05 - val_mse: 2.5269e-05 - val_mae: 0.0041 - val_mape: 601.1855
# Epoch 26/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.5919e-05 - mse: 1.5919e-05 - mae: 0.0029 - mape: 306.2212 - val_loss: 1.0547e-05 - val_mse: 1.0547e-05 - val_mae: 0.0026 - val_mape: 524.8481
# Epoch 27/100
# 33/33 [==============================] - 4s 110ms/step - loss: 1.8429e-05 - mse: 1.8429e-05 - mae: 0.0031 - mape: 333.6412 - val_loss: 1.3576e-05 - val_mse: 1.3576e-05 - val_mae: 0.0029 - val_mape: 412.3814
# Epoch 28/100
# 33/33 [==============================] - 2s 64ms/step - loss: 1.5676e-05 - mse: 1.5676e-05 - mae: 0.0027 - mape: 293.8423 - val_loss: 3.0710e-05 - val_mse: 3.0710e-05 - val_mae: 0.0038 - val_mape: 932.1652
# Epoch 29/100
# 33/33 [==============================] - 2s 74ms/step - loss: 1.3666e-05 - mse: 1.3666e-05 - mae: 0.0026 - mape: 278.4140 - val_loss: 1.4972e-05 - val_mse: 1.4972e-05 - val_mae: 0.0029 - val_mape: 923.2555
# Epoch 30/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.3002e-05 - mse: 1.3002e-05 - mae: 0.0025 - mape: 254.7600 - val_loss: 8.9501e-06 - val_mse: 8.9501e-06 - val_mae: 0.0022 - val_mape: 557.8027
# Epoch 31/100
# 33/33 [==============================] - 2s 72ms/step - loss: 1.2896e-05 - mse: 1.2896e-05 - mae: 0.0025 - mape: 253.3674 - val_loss: 1.2252e-05 - val_mse: 1.2252e-05 - val_mae: 0.0025 - val_mape: 584.2813
# Epoch 32/100
# 33/33 [==============================] - 4s 117ms/step - loss: 1.3053e-05 - mse: 1.3053e-05 - mae: 0.0025 - mape: 234.8689 - val_loss: 1.7644e-05 - val_mse: 1.7644e-05 - val_mae: 0.0036 - val_mape: 413.2598
# Epoch 33/100
# 33/33 [==============================] - 3s 98ms/step - loss: 1.6303e-05 - mse: 1.6303e-05 - mae: 0.0029 - mape: 325.0795 - val_loss: 2.5165e-05 - val_mse: 2.5165e-05 - val_mae: 0.0041 - val_mape: 964.7766
# Epoch 34/100
# 33/33 [==============================] - 3s 83ms/step - loss: 1.5322e-05 - mse: 1.5322e-05 - mae: 0.0027 - mape: 276.6958 - val_loss: 9.1245e-06 - val_mse: 9.1245e-06 - val_mae: 0.0022 - val_mape: 357.2935
# Epoch 35/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.4311e-05 - mse: 1.4311e-05 - mae: 0.0026 - mape: 278.7331 - val_loss: 9.9901e-06 - val_mse: 9.9901e-06 - val_mae: 0.0027 - val_mape: 371.0465
# Epoch 36/100
# 33/33 [==============================] - 3s 88ms/step - loss: 1.2927e-05 - mse: 1.2927e-05 - mae: 0.0025 - mape: 245.3267 - val_loss: 6.5474e-06 - val_mse: 6.5474e-06 - val_mae: 0.0019 - val_mape: 444.1646
# Epoch 37/100
# 33/33 [==============================] - 3s 85ms/step - loss: 1.2748e-05 - mse: 1.2748e-05 - mae: 0.0024 - mape: 254.3044 - val_loss: 6.5073e-06 - val_mse: 6.5073e-06 - val_mae: 0.0017 - val_mape: 442.1799
# Epoch 38/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.1959e-05 - mse: 1.1959e-05 - mae: 0.0023 - mape: 225.2415 - val_loss: 7.8967e-06 - val_mse: 7.8967e-06 - val_mae: 0.0021 - val_mape: 616.9183
# Epoch 39/100
# 33/33 [==============================] - 2s 70ms/step - loss: 1.3157e-05 - mse: 1.3157e-05 - mae: 0.0026 - mape: 292.8080 - val_loss: 5.5243e-05 - val_mse: 5.5243e-05 - val_mae: 0.0070 - val_mape: 933.4254
# Epoch 40/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.3110e-05 - mse: 1.3110e-05 - mae: 0.0025 - mape: 264.1735 - val_loss: 2.1155e-05 - val_mse: 2.1155e-05 - val_mae: 0.0040 - val_mape: 517.9520
# Epoch 41/100
# 33/33 [==============================] - 3s 84ms/step - loss: 1.3743e-05 - mse: 1.3743e-05 - mae: 0.0027 - mape: 293.8292 - val_loss: 1.7208e-05 - val_mse: 1.7208e-05 - val_mae: 0.0031 - val_mape: 973.3494
# Epoch 42/100
# 33/33 [==============================] - 3s 92ms/step - loss: 1.6420e-05 - mse: 1.6420e-05 - mae: 0.0030 - mape: 349.8176 - val_loss: 1.2819e-05 - val_mse: 1.2819e-05 - val_mae: 0.0029 - val_mape: 490.2194
# Epoch 43/100
# 33/33 [==============================] - 2s 72ms/step - loss: 1.4325e-05 - mse: 1.4325e-05 - mae: 0.0027 - mape: 298.3844 - val_loss: 1.2426e-05 - val_mse: 1.2426e-05 - val_mae: 0.0029 - val_mape: 804.7635
# Epoch 44/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.3006e-05 - mse: 1.3006e-05 - mae: 0.0025 - mape: 291.5714 - val_loss: 1.1800e-05 - val_mse: 1.1800e-05 - val_mae: 0.0026 - val_mape: 625.9872
# Epoch 45/100
# 33/33 [==============================] - 2s 75ms/step - loss: 1.2204e-05 - mse: 1.2204e-05 - mae: 0.0024 - mape: 242.7509 - val_loss: 6.5592e-06 - val_mse: 6.5592e-06 - val_mae: 0.0018 - val_mape: 362.8649
# Epoch 46/100
# 33/33 [==============================] - 6s 186ms/step - loss: 1.2808e-05 - mse: 1.2808e-05 - mae: 0.0024 - mape: 247.9773 - val_loss: 7.1937e-06 - val_mse: 7.1937e-06 - val_mae: 0.0021 - val_mape: 277.2759
# Epoch 47/100
# 33/33 [==============================] - 5s 163ms/step - loss: 1.3350e-05 - mse: 1.3350e-05 - mae: 0.0025 - mape: 250.9323 - val_loss: 5.9005e-06 - val_mse: 5.9005e-06 - val_mae: 0.0017 - val_mape: 367.5906
# Epoch 48/100
# 33/33 [==============================] - 6s 194ms/step - loss: 1.3379e-05 - mse: 1.3379e-05 - mae: 0.0025 - mape: 263.3623 - val_loss: 6.1022e-05 - val_mse: 6.1022e-05 - val_mae: 0.0062 - val_mape: 934.1379
# Epoch 49/100
# 33/33 [==============================] - 4s 126ms/step - loss: 1.2954e-05 - mse: 1.2954e-05 - mae: 0.0024 - mape: 247.3731 - val_loss: 6.5716e-06 - val_mse: 6.5716e-06 - val_mae: 0.0017 - val_mape: 516.9648
# Epoch 50/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.1446e-05 - mse: 1.1446e-05 - mae: 0.0024 - mape: 257.3010 - val_loss: 7.2995e-06 - val_mse: 7.2995e-06 - val_mae: 0.0019 - val_mape: 354.7848
# Epoch 51/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.3383e-05 - mse: 1.3383e-05 - mae: 0.0026 - mape: 285.7063 - val_loss: 6.0943e-06 - val_mse: 6.0943e-06 - val_mae: 0.0018 - val_mape: 271.5939
# Epoch 52/100
# 33/33 [==============================] - 3s 82ms/step - loss: 1.1758e-05 - mse: 1.1758e-05 - mae: 0.0023 - mape: 241.3614 - val_loss: 1.1087e-05 - val_mse: 1.1087e-05 - val_mae: 0.0026 - val_mape: 372.3337
# Epoch 53/100
# 33/33 [==============================] - 3s 95ms/step - loss: 1.2004e-05 - mse: 1.2004e-05 - mae: 0.0025 - mape: 297.3747 - val_loss: 1.3490e-05 - val_mse: 1.3490e-05 - val_mae: 0.0031 - val_mape: 343.4781
# Epoch 54/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.1831e-05 - mse: 1.1831e-05 - mae: 0.0024 - mape: 230.8566 - val_loss: 2.4335e-05 - val_mse: 2.4335e-05 - val_mae: 0.0039 - val_mape: 1196.0497
# Epoch 55/100
# 33/33 [==============================] - 2s 65ms/step - loss: 1.4859e-05 - mse: 1.4859e-05 - mae: 0.0028 - mape: 333.9008 - val_loss: 2.0488e-05 - val_mse: 2.0488e-05 - val_mae: 0.0036 - val_mape: 513.7726
# Epoch 56/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.0903e-05 - mse: 1.0903e-05 - mae: 0.0022 - mape: 214.4991 - val_loss: 1.4494e-05 - val_mse: 1.4494e-05 - val_mae: 0.0032 - val_mape: 570.7839
# Epoch 57/100
# 33/33 [==============================] - 2s 71ms/step - loss: 1.0611e-05 - mse: 1.0611e-05 - mae: 0.0022 - mape: 230.1374 - val_loss: 1.8422e-05 - val_mse: 1.8422e-05 - val_mae: 0.0031 - val_mape: 612.6714
# Epoch 58/100
# 33/33 [==============================] - 3s 103ms/step - loss: 1.3549e-05 - mse: 1.3549e-05 - mae: 0.0025 - mape: 266.8644 - val_loss: 1.2078e-05 - val_mse: 1.2078e-05 - val_mae: 0.0029 - val_mape: 749.8684
# Epoch 59/100
# 33/33 [==============================] - 2s 65ms/step - loss: 1.2980e-05 - mse: 1.2980e-05 - mae: 0.0024 - mape: 245.2027 - val_loss: 1.2489e-05 - val_mse: 1.2489e-05 - val_mae: 0.0028 - val_mape: 512.4926
# Epoch 60/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.0864e-05 - mse: 1.0864e-05 - mae: 0.0022 - mape: 227.3893 - val_loss: 7.7971e-06 - val_mse: 7.7971e-06 - val_mae: 0.0021 - val_mape: 300.6191
# Epoch 61/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.2441e-05 - mse: 1.2441e-05 - mae: 0.0025 - mape: 266.5831 - val_loss: 6.2467e-06 - val_mse: 6.2467e-06 - val_mae: 0.0017 - val_mape: 390.9347
# Epoch 62/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.0676e-05 - mse: 1.0676e-05 - mae: 0.0022 - mape: 210.4126 - val_loss: 8.7967e-06 - val_mse: 8.7967e-06 - val_mae: 0.0022 - val_mape: 629.0874
# Epoch 63/100
# 33/33 [==============================] - 4s 107ms/step - loss: 1.1682e-05 - mse: 1.1682e-05 - mae: 0.0023 - mape: 219.9520 - val_loss: 2.1459e-05 - val_mse: 2.1459e-05 - val_mae: 0.0035 - val_mape: 761.0795
# Epoch 64/100
# 33/33 [==============================] - 2s 64ms/step - loss: 1.1412e-05 - mse: 1.1412e-05 - mae: 0.0023 - mape: 236.4524 - val_loss: 2.8161e-05 - val_mse: 2.8161e-05 - val_mae: 0.0042 - val_mape: 1059.5751
# Epoch 65/100
# 33/33 [==============================] - 2s 65ms/step - loss: 1.2901e-05 - mse: 1.2901e-05 - mae: 0.0025 - mape: 284.6438 - val_loss: 1.0627e-05 - val_mse: 1.0627e-05 - val_mae: 0.0025 - val_mape: 646.8945
# Epoch 66/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.1943e-05 - mse: 1.1943e-05 - mae: 0.0023 - mape: 234.3668 - val_loss: 6.6207e-06 - val_mse: 6.6207e-06 - val_mae: 0.0018 - val_mape: 229.4551
# Epoch 67/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.1242e-05 - mse: 1.1242e-05 - mae: 0.0022 - mape: 212.2516 - val_loss: 1.6453e-05 - val_mse: 1.6453e-05 - val_mae: 0.0037 - val_mape: 520.8671
# Epoch 68/100
# 33/33 [==============================] - 4s 115ms/step - loss: 1.2270e-05 - mse: 1.2270e-05 - mae: 0.0024 - mape: 231.1463 - val_loss: 1.6288e-05 - val_mse: 1.6288e-05 - val_mae: 0.0034 - val_mape: 600.0034
# Epoch 69/100
# 33/33 [==============================] - 2s 65ms/step - loss: 1.2924e-05 - mse: 1.2924e-05 - mae: 0.0025 - mape: 285.9662 - val_loss: 5.5119e-06 - val_mse: 5.5119e-06 - val_mae: 0.0016 - val_mape: 368.3135
# Epoch 70/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.3380e-05 - mse: 1.3380e-05 - mae: 0.0026 - mape: 278.7384 - val_loss: 8.5067e-06 - val_mse: 8.5067e-06 - val_mae: 0.0020 - val_mape: 596.6533
# Epoch 71/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.1664e-05 - mse: 1.1664e-05 - mae: 0.0023 - mape: 207.8506 - val_loss: 1.7058e-05 - val_mse: 1.7058e-05 - val_mae: 0.0033 - val_mape: 477.4311
# Epoch 72/100
# 33/33 [==============================] - 2s 65ms/step - loss: 1.0947e-05 - mse: 1.0947e-05 - mae: 0.0021 - mape: 193.0528 - val_loss: 5.2683e-06 - val_mse: 5.2683e-06 - val_mae: 0.0015 - val_mape: 407.8109
# Epoch 73/100
# 33/33 [==============================] - 3s 98ms/step - loss: 1.0696e-05 - mse: 1.0696e-05 - mae: 0.0022 - mape: 228.8502 - val_loss: 9.5265e-06 - val_mse: 9.5265e-06 - val_mae: 0.0022 - val_mape: 565.9191
# Epoch 74/100
# 33/33 [==============================] - 3s 75ms/step - loss: 1.1763e-05 - mse: 1.1763e-05 - mae: 0.0023 - mape: 250.9969 - val_loss: 5.5784e-06 - val_mse: 5.5784e-06 - val_mae: 0.0015 - val_mape: 376.1529
# Epoch 75/100
# 33/33 [==============================] - 3s 77ms/step - loss: 1.1001e-05 - mse: 1.1001e-05 - mae: 0.0022 - mape: 219.9921 - val_loss: 1.5241e-05 - val_mse: 1.5241e-05 - val_mae: 0.0029 - val_mape: 708.5991
# Epoch 76/100
# 33/33 [==============================] - 3s 88ms/step - loss: 1.4493e-05 - mse: 1.4493e-05 - mae: 0.0027 - mape: 293.9685 - val_loss: 5.3593e-06 - val_mse: 5.3593e-06 - val_mae: 0.0016 - val_mape: 332.7115
# Epoch 77/100
# 33/33 [==============================] - 2s 65ms/step - loss: 1.1450e-05 - mse: 1.1450e-05 - mae: 0.0022 - mape: 229.2106 - val_loss: 1.3650e-05 - val_mse: 1.3650e-05 - val_mae: 0.0027 - val_mape: 690.5162
# Epoch 78/100
# 33/33 [==============================] - 4s 115ms/step - loss: 1.1617e-05 - mse: 1.1617e-05 - mae: 0.0023 - mape: 220.8552 - val_loss: 1.4859e-05 - val_mse: 1.4859e-05 - val_mae: 0.0030 - val_mape: 423.8571
# Epoch 79/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.1354e-05 - mse: 1.1354e-05 - mae: 0.0023 - mape: 248.1664 - val_loss: 7.5361e-06 - val_mse: 7.5361e-06 - val_mae: 0.0020 - val_mape: 274.0063
# Epoch 80/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.2589e-05 - mse: 1.2589e-05 - mae: 0.0023 - mape: 240.9466 - val_loss: 7.9323e-06 - val_mse: 7.9323e-06 - val_mae: 0.0020 - val_mape: 626.4658
# Epoch 81/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.0764e-05 - mse: 1.0764e-05 - mae: 0.0022 - mape: 205.0597 - val_loss: 1.0938e-05 - val_mse: 1.0938e-05 - val_mae: 0.0028 - val_mape: 372.3063
# Epoch 82/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.0482e-05 - mse: 1.0482e-05 - mae: 0.0021 - mape: 205.7330 - val_loss: 6.1935e-06 - val_mse: 6.1935e-06 - val_mae: 0.0018 - val_mape: 318.2731
# Epoch 83/100
# 33/33 [==============================] - 4s 111ms/step - loss: 1.0587e-05 - mse: 1.0587e-05 - mae: 0.0022 - mape: 204.5571 - val_loss: 1.0698e-05 - val_mse: 1.0698e-05 - val_mae: 0.0026 - val_mape: 399.8333
# Epoch 84/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.1924e-05 - mse: 1.1924e-05 - mae: 0.0023 - mape: 248.5516 - val_loss: 5.1893e-06 - val_mse: 5.1893e-06 - val_mae: 0.0014 - val_mape: 378.2804
# Epoch 85/100
# 33/33 [==============================] - 2s 76ms/step - loss: 1.1805e-05 - mse: 1.1805e-05 - mae: 0.0024 - mape: 244.9799 - val_loss: 7.5928e-06 - val_mse: 7.5928e-06 - val_mae: 0.0020 - val_mape: 459.1582
# Epoch 86/100
# 33/33 [==============================] - 2s 72ms/step - loss: 1.1257e-05 - mse: 1.1257e-05 - mae: 0.0023 - mape: 245.2233 - val_loss: 6.4826e-06 - val_mse: 6.4826e-06 - val_mae: 0.0018 - val_mape: 394.6700
# Epoch 87/100
# 33/33 [==============================] - 3s 75ms/step - loss: 1.2808e-05 - mse: 1.2808e-05 - mae: 0.0024 - mape: 244.5543 - val_loss: 7.1928e-06 - val_mse: 7.1928e-06 - val_mae: 0.0019 - val_mape: 596.6471
# Epoch 88/100
# 33/33 [==============================] - 4s 114ms/step - loss: 1.1826e-05 - mse: 1.1826e-05 - mae: 0.0023 - mape: 228.5738 - val_loss: 1.2000e-05 - val_mse: 1.2000e-05 - val_mae: 0.0029 - val_mape: 355.5622
# Epoch 89/100
# 33/33 [==============================] - 2s 70ms/step - loss: 1.0440e-05 - mse: 1.0440e-05 - mae: 0.0021 - mape: 205.2645 - val_loss: 1.6729e-05 - val_mse: 1.6729e-05 - val_mae: 0.0035 - val_mape: 715.2769
# Epoch 90/100
# 33/33 [==============================] - 2s 68ms/step - loss: 9.4745e-06 - mse: 9.4745e-06 - mae: 0.0019 - mape: 181.9132 - val_loss: 1.2837e-05 - val_mse: 1.2837e-05 - val_mae: 0.0029 - val_mape: 612.4460
# Epoch 91/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.1436e-05 - mse: 1.1436e-05 - mae: 0.0023 - mape: 224.3100 - val_loss: 5.7987e-06 - val_mse: 5.7987e-06 - val_mae: 0.0016 - val_mape: 416.6715
# Epoch 92/100
# 33/33 [==============================] - 2s 70ms/step - loss: 1.0479e-05 - mse: 1.0479e-05 - mae: 0.0021 - mape: 204.4976 - val_loss: 5.1537e-06 - val_mse: 5.1537e-06 - val_mae: 0.0015 - val_mape: 387.2668
# Epoch 93/100
# 33/33 [==============================] - 4s 113ms/step - loss: 1.0704e-05 - mse: 1.0704e-05 - mae: 0.0021 - mape: 230.5056 - val_loss: 6.7784e-06 - val_mse: 6.7784e-06 - val_mae: 0.0017 - val_mape: 567.8055
# Epoch 94/100
# 33/33 [==============================] - 2s 74ms/step - loss: 1.2318e-05 - mse: 1.2318e-05 - mae: 0.0024 - mape: 241.9927 - val_loss: 7.0686e-06 - val_mse: 7.0686e-06 - val_mae: 0.0020 - val_mape: 350.5871
# Epoch 95/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.0806e-05 - mse: 1.0806e-05 - mae: 0.0022 - mape: 225.7971 - val_loss: 8.5261e-06 - val_mse: 8.5261e-06 - val_mae: 0.0022 - val_mape: 610.8986
# Epoch 96/100
# 33/33 [==============================] - 2s 73ms/step - loss: 1.0678e-05 - mse: 1.0678e-05 - mae: 0.0021 - mape: 212.9148 - val_loss: 1.0903e-05 - val_mse: 1.0903e-05 - val_mae: 0.0025 - val_mape: 744.1476
# Epoch 97/100
# 33/33 [==============================] - 3s 80ms/step - loss: 1.0586e-05 - mse: 1.0586e-05 - mae: 0.0021 - mape: 191.2297 - val_loss: 1.7085e-05 - val_mse: 1.7085e-05 - val_mae: 0.0031 - val_mape: 419.6073
# Epoch 98/100
# 33/33 [==============================] - 3s 99ms/step - loss: 1.2052e-05 - mse: 1.2052e-05 - mae: 0.0024 - mape: 248.2498 - val_loss: 1.1949e-05 - val_mse: 1.1949e-05 - val_mae: 0.0030 - val_mape: 379.7755
# Epoch 99/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.0752e-05 - mse: 1.0752e-05 - mae: 0.0021 - mape: 194.1587 - val_loss: 8.1394e-06 - val_mse: 8.1394e-06 - val_mae: 0.0021 - val_mape: 291.4999
# Epoch 100/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.0346e-05 - mse: 1.0346e-05 - mae: 0.0021 - mape: 215.6595 - val_loss: 7.7211e-06 - val_mse: 7.7211e-06 - val_mae: 0.0022 - val_mape: 298.5925
# 21/21 [==============================] - 1s 10ms/step
# 9/9 [==============================] - 0s 6ms/step
#
# Time: 331.75
# MSE: 1.03e-05
# MAE: 2.14e-03
# MAPE: 2.16e+02

# %% [markdown]
# ## Plot Result

# %%
fig, ((ax1, ax2)) = plt.subplots(2, 1, figsize=(10, 8))

ax1.plot(train_pred_detrend[:,0,0], zorder=2, label='Insulator 1 - Observed')
ax1.plot(X_input_train[:,0,0], zorder=2, label='Insulator 1 - Predicted')
ax1.set_ylabel('Normalized Value')
ax1.set_xlabel('Sample Index')
ax1.axis([0, len(train_pred_detrend[:,0,0]), -0.035, 0.045])
ax1.grid(linestyle = '--', linewidth = 0.5, zorder=0)
ax1.legend(loc="upper right", bbox_to_anchor=(1, 0.25), fancybox=True, shadow=False, ncol=1)

ax2.plot(train_pred_detrend[:,0,2], zorder=2, label='Insulator 2 - Observed')
ax2.plot(X_input_train[:,0,2],zorder=2, label='Insulator 2 - Predicted')
ax2.set_ylabel('Normalized Value')
ax2.set_xlabel('Sample Index')
ax2.axis([0, len(train_pred_detrend[:,0,0]), -0.035, 0.045])
ax2.grid(linestyle = '--', linewidth = 0.5, zorder=0)
ax2.legend(loc='lower right', fancybox=True, shadow=False, ncol=1)
plt.show 
# plt.savefig('Pred_1.pdf')
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Hyperparameters Optimization (Optuna)

# %%
def attention(n_hidden, ativacao, lr):

    input_train = Input(shape=(X_input_train.shape[1], X_input_train.shape[2]-1))
    output_train = Input(shape=(X_output_train.shape[1], X_output_train.shape[2]-1))

    encoder_stack_h, encoder_last_h, encoder_last_c = LSTM(n_hidden, activation=ativacao, dropout=0.2, recurrent_dropout=0.2, return_state=True, return_sequences=True)(input_train)
    encoder_last_h = BatchNormalization(momentum=0.6)(encoder_last_h)
    encoder_last_c = BatchNormalization(momentum=0.6)(encoder_last_c)

    decoder_input = RepeatVector(output_train.shape[1])(encoder_last_h)
    decoder_stack_h = LSTM(n_hidden, activation=ativacao, dropout=0.2, recurrent_dropout=0.2, return_state=False, return_sequences=True)(decoder_input, initial_state=[encoder_last_h, encoder_last_c])

    attention = dot([decoder_stack_h, encoder_stack_h], axes=[2, 2])
    attention = Activation('softmax')(attention)
    context = dot([attention, encoder_stack_h], axes=[2,1])
    context = BatchNormalization(momentum=0.6)(context)

    decoder_combined_context = concatenate([context, decoder_stack_h])
    out = TimeDistributed(Dense(output_train.shape[2]))(decoder_combined_context)

    model = Model(inputs=input_train, outputs=out)
    opt = Adam(learning_rate=lr)
    model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mse', 'mae', 'mape'])

    for i in range(1):
        es = EarlyStopping(monitor='val_loss', mode='min', patience=50)
        history = model.fit(X_input_train[:, :, :TOTAL], X_output_train[:, :, :TOTAL], validation_split=0.2, epochs=epc, verbose=1, callbacks=[es], batch_size=batch_siz)

        train_loss = history.history['loss']
        valid_loss = history.history['val_loss']
        mse = history.history['mse']
        mae = history.history['mae']
        mape = history.history['mape']
        model.save('model_forecasting_seq2seq.h5')

        train_pred_detrend = model.predict(X_input_train[:, :, :TOTAL])
        test_pred_detrend = model.predict(X_input_test[:, :, :TOTAL])
        train_true_detrend = X_output_train[:, :, :TOTAL]
        test_true_detrend = X_output_test[:, :, :TOTAL]
        data_final = dict()

    return mse[-1]

def objective(trial):
    x = trial.suggest_int('hidden_units', 10, 100)
    ativacao = trial.suggest_categorical("activation", ['relu', 'elu', 'tanh'])
    lr = trial.suggest_float('learning_rate', 0.001, 0.1)
    erro = attention(x, ativacao, lr)
    return erro

study = optuna.create_study()
study.optimize(objective, n_trials=10)

study.best_params  # E.g. {'x': 2.002108042}
# Out:
# [I 2023-03-06 12:10:56,763] A new study created in memory with name: no-name-a378267c-f370-480c-b7a3-30e8d341c58e
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 33/33 [==============================] - 12s 129ms/step - loss: 2.8919e-04 - mse: 2.8919e-04 - mae: 0.0112 - mape: 1443.7664 - val_loss: 1.6703e-05 - val_mse: 1.6703e-05 - val_mae: 0.0033 - val_mape: 425.8022
# Epoch 2/100
# 33/33 [==============================] - 2s 72ms/step - loss: 2.8545e-05 - mse: 2.8545e-05 - mae: 0.0038 - mape: 321.8771 - val_loss: 1.4962e-05 - val_mse: 1.4962e-05 - val_mae: 0.0030 - val_mape: 392.9543
# Epoch 3/100
# 33/33 [==============================] - 2s 64ms/step - loss: 2.3202e-05 - mse: 2.3202e-05 - mae: 0.0033 - mape: 320.8879 - val_loss: 1.6610e-05 - val_mse: 1.6610e-05 - val_mae: 0.0031 - val_mape: 616.4187
# Epoch 4/100
# 33/33 [==============================] - 2s 70ms/step - loss: 2.0949e-05 - mse: 2.0949e-05 - mae: 0.0031 - mape: 293.6327 - val_loss: 7.5773e-06 - val_mse: 7.5773e-06 - val_mae: 0.0021 - val_mape: 342.7128
# Epoch 5/100
# 33/33 [==============================] - 2s 65ms/step - loss: 1.9516e-05 - mse: 1.9516e-05 - mae: 0.0030 - mape: 292.5249 - val_loss: 2.4876e-05 - val_mse: 2.4876e-05 - val_mae: 0.0037 - val_mape: 547.1789
# Epoch 6/100
# 33/33 [==============================] - 4s 111ms/step - loss: 2.2526e-05 - mse: 2.2526e-05 - mae: 0.0033 - mape: 335.6269 - val_loss: 7.5347e-06 - val_mse: 7.5347e-06 - val_mae: 0.0021 - val_mape: 328.2210
# Epoch 7/100
# 33/33 [==============================] - 2s 65ms/step - loss: 2.2689e-05 - mse: 2.2689e-05 - mae: 0.0034 - mape: 357.8246 - val_loss: 1.3402e-05 - val_mse: 1.3402e-05 - val_mae: 0.0027 - val_mape: 854.4354
# Epoch 8/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.8580e-05 - mse: 1.8580e-05 - mae: 0.0029 - mape: 265.0063 - val_loss: 5.3832e-06 - val_mse: 5.3832e-06 - val_mae: 0.0017 - val_mape: 303.0919
# Epoch 9/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.8787e-05 - mse: 1.8787e-05 - mae: 0.0029 - mape: 253.8060 - val_loss: 7.6101e-06 - val_mse: 7.6101e-06 - val_mae: 0.0019 - val_mape: 565.8911
# Epoch 10/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.7685e-05 - mse: 1.7685e-05 - mae: 0.0028 - mape: 235.9504 - val_loss: 7.7860e-06 - val_mse: 7.7860e-06 - val_mae: 0.0021 - val_mape: 391.5427
# Epoch 11/100
# 33/33 [==============================] - 4s 112ms/step - loss: 2.1331e-05 - mse: 2.1331e-05 - mae: 0.0033 - mape: 326.7490 - val_loss: 1.4945e-05 - val_mse: 1.4945e-05 - val_mae: 0.0029 - val_mape: 527.4249
# Epoch 12/100
# 33/33 [==============================] - 2s 71ms/step - loss: 1.9673e-05 - mse: 1.9673e-05 - mae: 0.0030 - mape: 268.5002 - val_loss: 8.8881e-06 - val_mse: 8.8881e-06 - val_mae: 0.0024 - val_mape: 262.8444
# Epoch 13/100
# 33/33 [==============================] - 2s 70ms/step - loss: 2.1499e-05 - mse: 2.1499e-05 - mae: 0.0032 - mape: 328.9014 - val_loss: 7.8153e-06 - val_mse: 7.8153e-06 - val_mae: 0.0022 - val_mape: 218.3686
# Epoch 14/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.0049e-05 - mse: 2.0049e-05 - mae: 0.0031 - mape: 306.5779 - val_loss: 1.7246e-05 - val_mse: 1.7246e-05 - val_mae: 0.0038 - val_mape: 440.2347
# Epoch 15/100
# 33/33 [==============================] - 2s 72ms/step - loss: 2.0925e-05 - mse: 2.0925e-05 - mae: 0.0033 - mape: 358.1729 - val_loss: 9.1720e-06 - val_mse: 9.1720e-06 - val_mae: 0.0022 - val_mape: 432.5615
# Epoch 16/100
# 33/33 [==============================] - 4s 110ms/step - loss: 2.2013e-05 - mse: 2.2013e-05 - mae: 0.0033 - mape: 324.7881 - val_loss: 6.3330e-06 - val_mse: 6.3330e-06 - val_mae: 0.0018 - val_mape: 265.5248
# Epoch 17/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.9720e-05 - mse: 1.9720e-05 - mae: 0.0030 - mape: 286.1920 - val_loss: 1.3115e-05 - val_mse: 1.3115e-05 - val_mae: 0.0028 - val_mape: 729.6786
# Epoch 18/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.0963e-05 - mse: 2.0963e-05 - mae: 0.0033 - mape: 357.9162 - val_loss: 7.5982e-06 - val_mse: 7.5982e-06 - val_mae: 0.0020 - val_mape: 470.3949
# Epoch 19/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.7420e-05 - mse: 1.7420e-05 - mae: 0.0027 - mape: 243.2693 - val_loss: 9.7282e-06 - val_mse: 9.7282e-06 - val_mae: 0.0024 - val_mape: 334.4884
# Epoch 20/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.3192e-05 - mse: 2.3192e-05 - mae: 0.0035 - mape: 352.8167 - val_loss: 1.3277e-05 - val_mse: 1.3277e-05 - val_mae: 0.0027 - val_mape: 688.6842
# Epoch 21/100
# 33/33 [==============================] - 3s 107ms/step - loss: 2.0767e-05 - mse: 2.0767e-05 - mae: 0.0032 - mape: 348.3537 - val_loss: 8.2801e-06 - val_mse: 8.2801e-06 - val_mae: 0.0022 - val_mape: 443.3237
# Epoch 22/100
# 33/33 [==============================] - 2s 65ms/step - loss: 1.8920e-05 - mse: 1.8920e-05 - mae: 0.0030 - mape: 275.1753 - val_loss: 9.2151e-06 - val_mse: 9.2151e-06 - val_mae: 0.0024 - val_mape: 279.3670
# Epoch 23/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.9596e-05 - mse: 1.9596e-05 - mae: 0.0031 - mape: 326.0183 - val_loss: 6.7080e-06 - val_mse: 6.7080e-06 - val_mae: 0.0017 - val_mape: 429.0004
# Epoch 24/100
# 33/33 [==============================] - 2s 68ms/step - loss: 2.0617e-05 - mse: 2.0617e-05 - mae: 0.0032 - mape: 319.7834 - val_loss: 1.7100e-05 - val_mse: 1.7100e-05 - val_mae: 0.0035 - val_mape: 832.4227
# Epoch 25/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.8849e-05 - mse: 1.8849e-05 - mae: 0.0030 - mape: 285.2824 - val_loss: 1.3495e-05 - val_mse: 1.3495e-05 - val_mae: 0.0027 - val_mape: 462.9799
# Epoch 26/100
# 33/33 [==============================] - 3s 106ms/step - loss: 1.9890e-05 - mse: 1.9890e-05 - mae: 0.0031 - mape: 304.5851 - val_loss: 1.2993e-05 - val_mse: 1.2993e-05 - val_mae: 0.0029 - val_mape: 802.8424
# Epoch 27/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.9265e-05 - mse: 1.9265e-05 - mae: 0.0031 - mape: 317.9281 - val_loss: 1.5092e-05 - val_mse: 1.5092e-05 - val_mae: 0.0034 - val_mape: 411.4234
# Epoch 28/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.7745e-05 - mse: 1.7745e-05 - mae: 0.0029 - mape: 303.3809 - val_loss: 6.6640e-06 - val_mse: 6.6640e-06 - val_mae: 0.0018 - val_mape: 496.5389
# Epoch 29/100
# 33/33 [==============================] - 2s 66ms/step - loss: 2.3445e-05 - mse: 2.3445e-05 - mae: 0.0035 - mape: 370.2428 - val_loss: 8.1787e-06 - val_mse: 8.1787e-06 - val_mae: 0.0022 - val_mape: 265.1975
# Epoch 30/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.6670e-05 - mse: 1.6670e-05 - mae: 0.0028 - mape: 291.8152 - val_loss: 5.3099e-06 - val_mse: 5.3099e-06 - val_mae: 0.0015 - val_mape: 412.1358
# Epoch 31/100
# 33/33 [==============================] - 3s 89ms/step - loss: 1.9815e-05 - mse: 1.9815e-05 - mae: 0.0031 - mape: 317.8845 - val_loss: 2.1971e-05 - val_mse: 2.1971e-05 - val_mae: 0.0039 - val_mape: 675.2336
# Epoch 32/100
# 33/33 [==============================] - 3s 84ms/step - loss: 1.9829e-05 - mse: 1.9829e-05 - mae: 0.0032 - mape: 357.7675 - val_loss: 1.4178e-05 - val_mse: 1.4178e-05 - val_mae: 0.0031 - val_mape: 732.9753
# Epoch 33/100
# 33/33 [==============================] - 2s 70ms/step - loss: 1.8788e-05 - mse: 1.8788e-05 - mae: 0.0031 - mape: 322.3155 - val_loss: 7.5947e-06 - val_mse: 7.5947e-06 - val_mae: 0.0018 - val_mape: 700.8865
# Epoch 34/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.8656e-05 - mse: 1.8656e-05 - mae: 0.0031 - mape: 329.4682 - val_loss: 3.3137e-05 - val_mse: 3.3137e-05 - val_mae: 0.0051 - val_mape: 637.0650
# Epoch 35/100
# 33/33 [==============================] - 2s 68ms/step - loss: 2.1169e-05 - mse: 2.1169e-05 - mae: 0.0034 - mape: 395.4770 - val_loss: 1.4044e-05 - val_mse: 1.4044e-05 - val_mae: 0.0029 - val_mape: 484.0286
# Epoch 36/100
# 33/33 [==============================] - 3s 88ms/step - loss: 1.9846e-05 - mse: 1.9846e-05 - mae: 0.0033 - mape: 368.7625 - val_loss: 1.5391e-05 - val_mse: 1.5391e-05 - val_mae: 0.0030 - val_mape: 531.9277
# Epoch 37/100
# 33/33 [==============================] - 3s 87ms/step - loss: 1.7928e-05 - mse: 1.7928e-05 - mae: 0.0030 - mape: 321.8868 - val_loss: 5.4786e-06 - val_mse: 5.4786e-06 - val_mae: 0.0016 - val_mape: 416.8381
# Epoch 38/100
# 33/33 [==============================] - 2s 68ms/step - loss: 2.1459e-05 - mse: 2.1459e-05 - mae: 0.0033 - mape: 333.7155 - val_loss: 3.3709e-05 - val_mse: 3.3709e-05 - val_mae: 0.0055 - val_mape: 828.2048
# Epoch 39/100
# 33/33 [==============================] - 2s 68ms/step - loss: 2.2900e-05 - mse: 2.2900e-05 - mae: 0.0035 - mape: 387.3593 - val_loss: 4.5683e-06 - val_mse: 4.5683e-06 - val_mae: 0.0014 - val_mape: 321.5348
# Epoch 40/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.8633e-05 - mse: 1.8633e-05 - mae: 0.0031 - mape: 307.1400 - val_loss: 7.1545e-06 - val_mse: 7.1545e-06 - val_mae: 0.0017 - val_mape: 623.2788
# Epoch 41/100
# 33/33 [==============================] - 2s 74ms/step - loss: 1.8871e-05 - mse: 1.8871e-05 - mae: 0.0031 - mape: 312.2101 - val_loss: 4.0633e-05 - val_mse: 4.0633e-05 - val_mae: 0.0055 - val_mape: 805.2780
# Epoch 42/100
# 33/33 [==============================] - 3s 93ms/step - loss: 1.6505e-05 - mse: 1.6505e-05 - mae: 0.0028 - mape: 317.3409 - val_loss: 8.4120e-06 - val_mse: 8.4120e-06 - val_mae: 0.0020 - val_mape: 690.5966
# Epoch 43/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.0100e-05 - mse: 2.0100e-05 - mae: 0.0031 - mape: 304.5522 - val_loss: 1.0478e-05 - val_mse: 1.0478e-05 - val_mae: 0.0022 - val_mape: 833.8327
# Epoch 44/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.7649e-05 - mse: 1.7649e-05 - mae: 0.0030 - mape: 322.0915 - val_loss: 2.4923e-05 - val_mse: 2.4923e-05 - val_mae: 0.0044 - val_mape: 889.7671
# Epoch 45/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.8609e-05 - mse: 1.8609e-05 - mae: 0.0031 - mape: 343.6923 - val_loss: 3.7769e-05 - val_mse: 3.7769e-05 - val_mae: 0.0047 - val_mape: 1065.7517
# Epoch 46/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.9173e-05 - mse: 1.9173e-05 - mae: 0.0032 - mape: 368.1607 - val_loss: 6.3780e-06 - val_mse: 6.3780e-06 - val_mae: 0.0018 - val_mape: 498.4966
# Epoch 47/100
# 33/33 [==============================] - 3s 105ms/step - loss: 1.8171e-05 - mse: 1.8171e-05 - mae: 0.0029 - mape: 279.0068 - val_loss: 6.0228e-06 - val_mse: 6.0228e-06 - val_mae: 0.0019 - val_mape: 270.2522
# Epoch 48/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.8375e-05 - mse: 1.8375e-05 - mae: 0.0030 - mape: 314.2963 - val_loss: 2.4149e-05 - val_mse: 2.4149e-05 - val_mae: 0.0044 - val_mape: 1106.6119
# Epoch 49/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.8015e-05 - mse: 1.8015e-05 - mae: 0.0030 - mape: 315.4791 - val_loss: 4.2805e-06 - val_mse: 4.2805e-06 - val_mae: 0.0013 - val_mape: 355.0552
# Epoch 50/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.9234e-05 - mse: 1.9234e-05 - mae: 0.0032 - mape: 386.4960 - val_loss: 1.7256e-05 - val_mse: 1.7256e-05 - val_mae: 0.0036 - val_mape: 563.2368
# Epoch 51/100
# 33/33 [==============================] - 2s 68ms/step - loss: 2.4976e-05 - mse: 2.4976e-05 - mae: 0.0037 - mape: 467.8430 - val_loss: 7.2755e-06 - val_mse: 7.2755e-06 - val_mae: 0.0020 - val_mape: 447.4230
# Epoch 52/100
# 33/33 [==============================] - 4s 110ms/step - loss: 2.1105e-05 - mse: 2.1105e-05 - mae: 0.0033 - mape: 361.0654 - val_loss: 3.5794e-05 - val_mse: 3.5794e-05 - val_mae: 0.0057 - val_mape: 846.8964
# Epoch 53/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.8433e-05 - mse: 1.8433e-05 - mae: 0.0031 - mape: 365.6169 - val_loss: 1.1117e-05 - val_mse: 1.1117e-05 - val_mae: 0.0027 - val_mape: 718.5337
# Epoch 54/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.8910e-05 - mse: 1.8910e-05 - mae: 0.0031 - mape: 349.4023 - val_loss: 8.0176e-05 - val_mse: 8.0176e-05 - val_mae: 0.0087 - val_mape: 1890.3960
# Epoch 55/100
# 33/33 [==============================] - 2s 67ms/step - loss: 2.0955e-05 - mse: 2.0955e-05 - mae: 0.0034 - mape: 388.8429 - val_loss: 2.4831e-05 - val_mse: 2.4831e-05 - val_mae: 0.0046 - val_mape: 791.6611
# Epoch 56/100
# 33/33 [==============================] - 2s 67ms/step - loss: 2.5165e-05 - mse: 2.5165e-05 - mae: 0.0037 - mape: 419.4179 - val_loss: 2.1417e-05 - val_mse: 2.1417e-05 - val_mae: 0.0040 - val_mape: 679.3506
# Epoch 57/100
# 33/33 [==============================] - 4s 108ms/step - loss: 1.9237e-05 - mse: 1.9237e-05 - mae: 0.0031 - mape: 334.2379 - val_loss: 4.3736e-06 - val_mse: 4.3736e-06 - val_mae: 0.0014 - val_mape: 340.0515
# Epoch 58/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.5886e-05 - mse: 1.5886e-05 - mae: 0.0027 - mape: 314.4352 - val_loss: 4.7111e-06 - val_mse: 4.7111e-06 - val_mae: 0.0015 - val_mape: 321.8459
# Epoch 59/100
# 33/33 [==============================] - 2s 70ms/step - loss: 1.9918e-05 - mse: 1.9918e-05 - mae: 0.0032 - mape: 358.7263 - val_loss: 8.0477e-06 - val_mse: 8.0477e-06 - val_mae: 0.0023 - val_mape: 334.9606
# Epoch 60/100
# 33/33 [==============================] - 2s 67ms/step - loss: 2.0450e-05 - mse: 2.0450e-05 - mae: 0.0033 - mape: 376.0269 - val_loss: 2.8489e-05 - val_mse: 2.8489e-05 - val_mae: 0.0050 - val_mape: 514.3477
# Epoch 61/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.0365e-05 - mse: 2.0365e-05 - mae: 0.0032 - mape: 329.9152 - val_loss: 6.8297e-06 - val_mse: 6.8297e-06 - val_mae: 0.0020 - val_mape: 392.0881
# Epoch 62/100
# 33/33 [==============================] - 4s 111ms/step - loss: 1.7345e-05 - mse: 1.7345e-05 - mae: 0.0030 - mape: 354.8762 - val_loss: 1.6009e-05 - val_mse: 1.6009e-05 - val_mae: 0.0033 - val_mape: 945.9559
# Epoch 63/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.8228e-05 - mse: 1.8228e-05 - mae: 0.0030 - mape: 330.4728 - val_loss: 8.1871e-06 - val_mse: 8.1871e-06 - val_mae: 0.0023 - val_mape: 321.3826
# Epoch 64/100
# 33/33 [==============================] - 2s 71ms/step - loss: 2.0822e-05 - mse: 2.0822e-05 - mae: 0.0033 - mape: 374.3733 - val_loss: 1.2753e-05 - val_mse: 1.2753e-05 - val_mae: 0.0029 - val_mape: 714.7610
# Epoch 65/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.8673e-05 - mse: 1.8673e-05 - mae: 0.0031 - mape: 340.6518 - val_loss: 1.7998e-05 - val_mse: 1.7998e-05 - val_mae: 0.0036 - val_mape: 822.8480
# Epoch 66/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.1070e-05 - mse: 2.1070e-05 - mae: 0.0035 - mape: 420.7382 - val_loss: 2.6248e-05 - val_mse: 2.6248e-05 - val_mae: 0.0040 - val_mape: 834.2903
# Epoch 67/100
# 33/33 [==============================] - 4s 113ms/step - loss: 1.4790e-05 - mse: 1.4790e-05 - mae: 0.0026 - mape: 268.1506 - val_loss: 3.5000e-05 - val_mse: 3.5000e-05 - val_mae: 0.0055 - val_mape: 951.7094
# Epoch 68/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.6400e-05 - mse: 1.6400e-05 - mae: 0.0028 - mape: 291.3981 - val_loss: 1.8577e-05 - val_mse: 1.8577e-05 - val_mae: 0.0036 - val_mape: 585.0111
# Epoch 69/100
# 33/33 [==============================] - 2s 67ms/step - loss: 2.3323e-05 - mse: 2.3323e-05 - mae: 0.0036 - mape: 425.8602 - val_loss: 1.3060e-04 - val_mse: 1.3060e-04 - val_mae: 0.0100 - val_mape: 1493.5719
# Epoch 70/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.6136e-05 - mse: 1.6136e-05 - mae: 0.0028 - mape: 292.0082 - val_loss: 7.5871e-06 - val_mse: 7.5871e-06 - val_mae: 0.0022 - val_mape: 290.7803
# Epoch 71/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.7396e-05 - mse: 1.7396e-05 - mae: 0.0030 - mape: 336.1019 - val_loss: 8.7141e-06 - val_mse: 8.7141e-06 - val_mae: 0.0020 - val_mape: 719.3842
# Epoch 72/100
# 33/33 [==============================] - 4s 114ms/step - loss: 1.8361e-05 - mse: 1.8361e-05 - mae: 0.0030 - mape: 329.9020 - val_loss: 2.7767e-05 - val_mse: 2.7767e-05 - val_mae: 0.0046 - val_mape: 751.7345
# Epoch 73/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.7257e-05 - mse: 1.7257e-05 - mae: 0.0030 - mape: 349.2615 - val_loss: 3.4655e-05 - val_mse: 3.4655e-05 - val_mae: 0.0051 - val_mape: 858.7719
# Epoch 74/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.1653e-05 - mse: 2.1653e-05 - mae: 0.0034 - mape: 397.1339 - val_loss: 4.4923e-05 - val_mse: 4.4923e-05 - val_mae: 0.0051 - val_mape: 1628.4218
# Epoch 75/100
# 33/33 [==============================] - 2s 72ms/step - loss: 1.8634e-05 - mse: 1.8634e-05 - mae: 0.0032 - mape: 335.7791 - val_loss: 7.0809e-06 - val_mse: 7.0809e-06 - val_mae: 0.0021 - val_mape: 416.0763
# Epoch 76/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.6735e-05 - mse: 1.6735e-05 - mae: 0.0030 - mape: 358.0869 - val_loss: 8.2232e-06 - val_mse: 8.2232e-06 - val_mae: 0.0023 - val_mape: 441.9179
# Epoch 77/100
# 33/33 [==============================] - 4s 109ms/step - loss: 1.5712e-05 - mse: 1.5712e-05 - mae: 0.0028 - mape: 298.2614 - val_loss: 5.2225e-06 - val_mse: 5.2225e-06 - val_mae: 0.0014 - val_mape: 519.9839
# Epoch 78/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.6146e-05 - mse: 1.6146e-05 - mae: 0.0029 - mape: 339.1387 - val_loss: 7.1126e-05 - val_mse: 7.1126e-05 - val_mae: 0.0080 - val_mape: 1799.5220
# Epoch 79/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.8960e-05 - mse: 1.8960e-05 - mae: 0.0031 - mape: 335.1583 - val_loss: 9.1333e-06 - val_mse: 9.1333e-06 - val_mae: 0.0021 - val_mape: 686.7612
# Epoch 80/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.6274e-05 - mse: 1.6274e-05 - mae: 0.0028 - mape: 334.1086 - val_loss: 2.0773e-05 - val_mse: 2.0773e-05 - val_mae: 0.0040 - val_mape: 593.5411
# Epoch 81/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.6810e-05 - mse: 1.6810e-05 - mae: 0.0029 - mape: 313.3958 - val_loss: 5.4062e-06 - val_mse: 5.4062e-06 - val_mae: 0.0018 - val_mape: 230.5339
# Epoch 82/100
# 33/33 [==============================] - 4s 111ms/step - loss: 1.5193e-05 - mse: 1.5193e-05 - mae: 0.0027 - mape: 282.3882 - val_loss: 1.8176e-04 - val_mse: 1.8176e-04 - val_mae: 0.0123 - val_mape: 1407.6709
# Epoch 83/100
# 33/33 [==============================] - 2s 72ms/step - loss: 1.6379e-05 - mse: 1.6379e-05 - mae: 0.0030 - mape: 330.0352 - val_loss: 3.9312e-05 - val_mse: 3.9312e-05 - val_mae: 0.0054 - val_mape: 967.1451
# Epoch 84/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.7378e-05 - mse: 1.7378e-05 - mae: 0.0030 - mape: 336.8886 - val_loss: 6.6138e-05 - val_mse: 6.6138e-05 - val_mae: 0.0078 - val_mape: 1716.1501
# Epoch 85/100
# 33/33 [==============================] - 2s 74ms/step - loss: 1.9551e-05 - mse: 1.9551e-05 - mae: 0.0033 - mape: 413.7279 - val_loss: 1.5357e-05 - val_mse: 1.5357e-05 - val_mae: 0.0036 - val_mape: 470.3972
# Epoch 86/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.6359e-05 - mse: 1.6359e-05 - mae: 0.0029 - mape: 298.0366 - val_loss: 1.1799e-05 - val_mse: 1.1799e-05 - val_mae: 0.0026 - val_mape: 837.4645
# Epoch 87/100
# 33/33 [==============================] - 4s 109ms/step - loss: 1.5880e-05 - mse: 1.5880e-05 - mae: 0.0028 - mape: 300.2360 - val_loss: 4.8498e-06 - val_mse: 4.8498e-06 - val_mae: 0.0015 - val_mape: 315.1724
# Epoch 88/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.9131e-05 - mse: 1.9131e-05 - mae: 0.0031 - mape: 344.7204 - val_loss: 1.9591e-05 - val_mse: 1.9591e-05 - val_mae: 0.0036 - val_mape: 679.4041
# Epoch 89/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.9277e-05 - mse: 1.9277e-05 - mae: 0.0032 - mape: 367.8756 - val_loss: 3.2001e-05 - val_mse: 3.2001e-05 - val_mae: 0.0049 - val_mape: 601.0801
# Epoch 90/100
# 33/33 [==============================] - 2s 68ms/step - loss: 2.2801e-05 - mse: 2.2801e-05 - mae: 0.0036 - mape: 465.4885 - val_loss: 2.2217e-05 - val_mse: 2.2217e-05 - val_mae: 0.0045 - val_mape: 575.4941
# Epoch 91/100
# 33/33 [==============================] - 2s 64ms/step - loss: 1.6753e-05 - mse: 1.6753e-05 - mae: 0.0029 - mape: 306.5869 - val_loss: 3.1475e-05 - val_mse: 3.1475e-05 - val_mae: 0.0047 - val_mape: 783.4371
# Epoch 92/100
# 33/33 [==============================] - 4s 108ms/step - loss: 1.8154e-05 - mse: 1.8154e-05 - mae: 0.0030 - mape: 318.8688 - val_loss: 8.0503e-06 - val_mse: 8.0503e-06 - val_mae: 0.0022 - val_mape: 416.4572
# Epoch 93/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.8239e-05 - mse: 1.8239e-05 - mae: 0.0031 - mape: 356.1010 - val_loss: 8.0209e-06 - val_mse: 8.0209e-06 - val_mae: 0.0021 - val_mape: 287.7039
# Epoch 94/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.6525e-05 - mse: 1.6525e-05 - mae: 0.0029 - mape: 342.7770 - val_loss: 7.8217e-06 - val_mse: 7.8217e-06 - val_mae: 0.0023 - val_mape: 294.5528
# Epoch 95/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.3680e-05 - mse: 1.3680e-05 - mae: 0.0025 - mape: 248.4338 - val_loss: 1.7683e-05 - val_mse: 1.7683e-05 - val_mae: 0.0030 - val_mape: 1073.9565
# Epoch 96/100
# 33/33 [==============================] - 2s 68ms/step - loss: 2.7411e-05 - mse: 2.7411e-05 - mae: 0.0042 - mape: 526.1713 - val_loss: 2.0539e-05 - val_mse: 2.0539e-05 - val_mae: 0.0040 - val_mape: 469.8323
# Epoch 97/100
# 33/33 [==============================] - 4s 112ms/step - loss: 1.9663e-05 - mse: 1.9663e-05 - mae: 0.0033 - mape: 438.2528 - val_loss: 1.7354e-05 - val_mse: 1.7354e-05 - val_mae: 0.0038 - val_mape: 527.1191
# Epoch 98/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.7513e-05 - mse: 1.7513e-05 - mae: 0.0031 - mape: 343.6025 - val_loss: 4.7531e-06 - val_mse: 4.7531e-06 - val_mae: 0.0014 - val_mape: 325.8391
# Epoch 99/100
# 33/33 [==============================] - 2s 70ms/step - loss: 1.7602e-05 - mse: 1.7602e-05 - mae: 0.0030 - mape: 302.5804 - val_loss: 1.5616e-05 - val_mse: 1.5616e-05 - val_mae: 0.0035 - val_mape: 424.6084
# 21/21 [==============================] - 1s 7ms/step
# 9/9 [==============================] - 0s 8ms/step
# [I 2023-03-06 12:15:16,208] Trial 0 finished with value: 1.760158374963794e-05 and parameters: {'hidden_units': 13, 'activation': 'relu', 'learning_rate': 0.016828751559430893}. Best is trial 0 with value: 1.760158374963794e-05.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 33/33 [==============================] - 12s 88ms/step - loss: 0.0090 - mse: 0.0090 - mae: 0.0514 - mape: 8230.1240 - val_loss: 1.6852e-04 - val_mse: 1.6852e-04 - val_mae: 0.0113 - val_mape: 2684.7695
# Epoch 2/100
# 33/33 [==============================] - 2s 70ms/step - loss: 8.4601e-05 - mse: 8.4601e-05 - mae: 0.0070 - mape: 800.9440 - val_loss: 1.0247e-05 - val_mse: 1.0247e-05 - val_mae: 0.0022 - val_mape: 563.9208
# Epoch 3/100
# 33/33 [==============================] - 2s 70ms/step - loss: 2.6574e-05 - mse: 2.6574e-05 - mae: 0.0038 - mape: 319.4429 - val_loss: 1.7805e-05 - val_mse: 1.7805e-05 - val_mae: 0.0032 - val_mape: 974.0298
# Epoch 4/100
# 33/33 [==============================] - 3s 106ms/step - loss: 2.1501e-05 - mse: 2.1501e-05 - mae: 0.0032 - mape: 249.6976 - val_loss: 1.2396e-05 - val_mse: 1.2396e-05 - val_mae: 0.0029 - val_mape: 330.4926
# Epoch 5/100
# 33/33 [==============================] - 2s 66ms/step - loss: 2.0839e-05 - mse: 2.0839e-05 - mae: 0.0032 - mape: 281.0588 - val_loss: 2.2217e-05 - val_mse: 2.2217e-05 - val_mae: 0.0039 - val_mape: 1135.6366
# Epoch 6/100
# 33/33 [==============================] - 2s 67ms/step - loss: 2.3328e-05 - mse: 2.3328e-05 - mae: 0.0034 - mape: 331.6568 - val_loss: 1.0823e-05 - val_mse: 1.0823e-05 - val_mae: 0.0026 - val_mape: 355.9600
# Epoch 7/100
# 33/33 [==============================] - 2s 67ms/step - loss: 2.2453e-05 - mse: 2.2453e-05 - mae: 0.0033 - mape: 314.2689 - val_loss: 1.4195e-05 - val_mse: 1.4195e-05 - val_mae: 0.0026 - val_mape: 917.5483
# Epoch 8/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.4449e-05 - mse: 2.4449e-05 - mae: 0.0036 - mape: 361.0866 - val_loss: 9.9258e-06 - val_mse: 9.9258e-06 - val_mae: 0.0023 - val_mape: 596.5858
# Epoch 9/100
# 33/33 [==============================] - 4s 113ms/step - loss: 3.0777e-05 - mse: 3.0777e-05 - mae: 0.0040 - mape: 446.3127 - val_loss: 8.0739e-06 - val_mse: 8.0739e-06 - val_mae: 0.0021 - val_mape: 449.2563
# Epoch 10/100
# 33/33 [==============================] - 2s 67ms/step - loss: 2.3163e-05 - mse: 2.3163e-05 - mae: 0.0034 - mape: 318.7791 - val_loss: 9.4754e-06 - val_mse: 9.4754e-06 - val_mae: 0.0023 - val_mape: 405.9380
# Epoch 11/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.9086e-05 - mse: 2.9086e-05 - mae: 0.0039 - mape: 419.3711 - val_loss: 9.8109e-06 - val_mse: 9.8109e-06 - val_mae: 0.0022 - val_mape: 669.0383
# Epoch 12/100
# 33/33 [==============================] - 2s 66ms/step - loss: 2.1867e-05 - mse: 2.1867e-05 - mae: 0.0033 - mape: 297.1217 - val_loss: 1.4812e-05 - val_mse: 1.4812e-05 - val_mae: 0.0029 - val_mape: 554.9760
# Epoch 13/100
# 33/33 [==============================] - 2s 66ms/step - loss: 2.3510e-05 - mse: 2.3510e-05 - mae: 0.0035 - mape: 354.7440 - val_loss: 2.1779e-05 - val_mse: 2.1779e-05 - val_mae: 0.0043 - val_mape: 658.8260
# Epoch 14/100
# 33/33 [==============================] - 4s 115ms/step - loss: 1.7159e-05 - mse: 1.7159e-05 - mae: 0.0026 - mape: 220.6566 - val_loss: 7.9099e-06 - val_mse: 7.9099e-06 - val_mae: 0.0021 - val_mape: 260.0717
# Epoch 15/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.9073e-05 - mse: 1.9073e-05 - mae: 0.0030 - mape: 274.6349 - val_loss: 1.4539e-05 - val_mse: 1.4539e-05 - val_mae: 0.0029 - val_mape: 834.8907
# Epoch 16/100
# 33/33 [==============================] - 2s 71ms/step - loss: 2.4141e-05 - mse: 2.4141e-05 - mae: 0.0037 - mape: 409.4022 - val_loss: 1.8386e-05 - val_mse: 1.8386e-05 - val_mae: 0.0034 - val_mape: 994.5573
# Epoch 17/100
# 33/33 [==============================] - 2s 70ms/step - loss: 1.8372e-05 - mse: 1.8372e-05 - mae: 0.0029 - mape: 292.2833 - val_loss: 8.5478e-06 - val_mse: 8.5478e-06 - val_mae: 0.0023 - val_mape: 302.3179
# Epoch 18/100
# 33/33 [==============================] - 2s 68ms/step - loss: 2.1373e-05 - mse: 2.1373e-05 - mae: 0.0033 - mape: 346.0006 - val_loss: 2.3907e-05 - val_mse: 2.3907e-05 - val_mae: 0.0043 - val_mape: 1124.7416
# Epoch 19/100
# 33/33 [==============================] - 4s 110ms/step - loss: 2.1182e-05 - mse: 2.1182e-05 - mae: 0.0032 - mape: 322.0591 - val_loss: 1.0427e-05 - val_mse: 1.0427e-05 - val_mae: 0.0027 - val_mape: 333.0814
# Epoch 20/100
# 33/33 [==============================] - 2s 65ms/step - loss: 2.5681e-05 - mse: 2.5681e-05 - mae: 0.0037 - mape: 418.5223 - val_loss: 9.9621e-06 - val_mse: 9.9621e-06 - val_mae: 0.0025 - val_mape: 480.4201
# Epoch 21/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.7965e-05 - mse: 1.7965e-05 - mae: 0.0029 - mape: 300.3815 - val_loss: 1.5095e-05 - val_mse: 1.5095e-05 - val_mae: 0.0035 - val_mape: 454.3798
# Epoch 22/100
# 33/33 [==============================] - 2s 71ms/step - loss: 2.0011e-05 - mse: 2.0011e-05 - mae: 0.0030 - mape: 276.5926 - val_loss: 2.6454e-05 - val_mse: 2.6454e-05 - val_mae: 0.0038 - val_mape: 863.2166
# Epoch 23/100
# 33/33 [==============================] - 2s 68ms/step - loss: 3.2621e-05 - mse: 3.2621e-05 - mae: 0.0044 - mape: 499.2243 - val_loss: 1.5868e-05 - val_mse: 1.5868e-05 - val_mae: 0.0034 - val_mape: 510.4430
# Epoch 24/100
# 33/33 [==============================] - 4s 111ms/step - loss: 1.9942e-05 - mse: 1.9942e-05 - mae: 0.0031 - mape: 294.6248 - val_loss: 3.2284e-05 - val_mse: 3.2284e-05 - val_mae: 0.0046 - val_mape: 773.4652
# Epoch 25/100
# 33/33 [==============================] - 2s 66ms/step - loss: 2.1902e-05 - mse: 2.1902e-05 - mae: 0.0034 - mape: 389.6983 - val_loss: 8.0888e-06 - val_mse: 8.0888e-06 - val_mae: 0.0021 - val_mape: 530.3945
# Epoch 26/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.8530e-05 - mse: 1.8530e-05 - mae: 0.0030 - mape: 306.6700 - val_loss: 5.8248e-06 - val_mse: 5.8248e-06 - val_mae: 0.0015 - val_mape: 490.8013
# Epoch 27/100
# 33/33 [==============================] - 2s 70ms/step - loss: 1.6386e-05 - mse: 1.6386e-05 - mae: 0.0027 - mape: 267.2504 - val_loss: 1.7683e-05 - val_mse: 1.7683e-05 - val_mae: 0.0035 - val_mape: 709.5719
# Epoch 28/100
# 33/33 [==============================] - 2s 67ms/step - loss: 1.7490e-05 - mse: 1.7490e-05 - mae: 0.0028 - mape: 251.5086 - val_loss: 7.8583e-06 - val_mse: 7.8583e-06 - val_mae: 0.0022 - val_mape: 373.7765
# Epoch 29/100
# 33/33 [==============================] - 4s 111ms/step - loss: 1.9229e-05 - mse: 1.9229e-05 - mae: 0.0031 - mape: 316.0748 - val_loss: 5.6764e-06 - val_mse: 5.6764e-06 - val_mae: 0.0016 - val_mape: 448.6821
# Epoch 30/100
# 33/33 [==============================] - 2s 71ms/step - loss: 1.8390e-05 - mse: 1.8390e-05 - mae: 0.0029 - mape: 297.5161 - val_loss: 7.6327e-06 - val_mse: 7.6327e-06 - val_mae: 0.0021 - val_mape: 254.2840
# Epoch 31/100
# 33/33 [==============================] - 2s 70ms/step - loss: 1.7030e-05 - mse: 1.7030e-05 - mae: 0.0028 - mape: 278.1070 - val_loss: 6.8834e-06 - val_mse: 6.8834e-06 - val_mae: 0.0021 - val_mape: 301.0674
# Epoch 32/100
# 33/33 [==============================] - 2s 73ms/step - loss: 1.8690e-05 - mse: 1.8690e-05 - mae: 0.0031 - mape: 337.0142 - val_loss: 1.1088e-05 - val_mse: 1.1088e-05 - val_mae: 0.0024 - val_mape: 704.2095
# Epoch 33/100
# 33/33 [==============================] - 2s 75ms/step - loss: 1.7917e-05 - mse: 1.7917e-05 - mae: 0.0030 - mape: 356.2136 - val_loss: 4.5338e-05 - val_mse: 4.5338e-05 - val_mae: 0.0062 - val_mape: 1563.1683
# Epoch 34/100
# 33/33 [==============================] - 4s 107ms/step - loss: 1.7710e-05 - mse: 1.7710e-05 - mae: 0.0029 - mape: 319.3124 - val_loss: 7.9800e-05 - val_mse: 7.9800e-05 - val_mae: 0.0082 - val_mape: 823.8466
# Epoch 35/100
# 33/33 [==============================] - 2s 71ms/step - loss: 1.8673e-05 - mse: 1.8673e-05 - mae: 0.0031 - mape: 307.2790 - val_loss: 9.2857e-06 - val_mse: 9.2857e-06 - val_mae: 0.0022 - val_mape: 703.2449
# Epoch 36/100
# 33/33 [==============================] - 2s 70ms/step - loss: 1.7979e-05 - mse: 1.7979e-05 - mae: 0.0030 - mape: 295.8731 - val_loss: 7.8912e-06 - val_mse: 7.8912e-06 - val_mae: 0.0021 - val_mape: 399.0284
# Epoch 37/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.3965e-05 - mse: 2.3965e-05 - mae: 0.0036 - mape: 388.5772 - val_loss: 1.7314e-05 - val_mse: 1.7314e-05 - val_mae: 0.0037 - val_mape: 550.6430
# Epoch 38/100
# 33/33 [==============================] - 3s 78ms/step - loss: 1.5908e-05 - mse: 1.5908e-05 - mae: 0.0027 - mape: 269.7463 - val_loss: 7.2817e-06 - val_mse: 7.2817e-06 - val_mae: 0.0019 - val_mape: 421.7558
# Epoch 39/100
# 33/33 [==============================] - 3s 103ms/step - loss: 1.7175e-05 - mse: 1.7175e-05 - mae: 0.0029 - mape: 294.1533 - val_loss: 5.8235e-06 - val_mse: 5.8235e-06 - val_mae: 0.0016 - val_mape: 492.1414
# Epoch 40/100
# 33/33 [==============================] - 2s 73ms/step - loss: 2.5758e-05 - mse: 2.5758e-05 - mae: 0.0038 - mape: 419.4718 - val_loss: 9.7807e-06 - val_mse: 9.7807e-06 - val_mae: 0.0024 - val_mape: 556.8701
# Epoch 41/100
# 33/33 [==============================] - 2s 71ms/step - loss: 1.7811e-05 - mse: 1.7811e-05 - mae: 0.0029 - mape: 311.7274 - val_loss: 6.0279e-05 - val_mse: 6.0279e-05 - val_mae: 0.0075 - val_mape: 1019.1190
# Epoch 42/100
# 33/33 [==============================] - 2s 70ms/step - loss: 1.5258e-05 - mse: 1.5258e-05 - mae: 0.0026 - mape: 231.4954 - val_loss: 7.5299e-06 - val_mse: 7.5299e-06 - val_mae: 0.0020 - val_mape: 500.1610
# Epoch 43/100
# 33/33 [==============================] - 3s 97ms/step - loss: 1.7229e-05 - mse: 1.7229e-05 - mae: 0.0029 - mape: 283.4039 - val_loss: 6.1899e-06 - val_mse: 6.1899e-06 - val_mae: 0.0019 - val_mape: 349.2331
# Epoch 44/100
# 33/33 [==============================] - 3s 85ms/step - loss: 1.9701e-05 - mse: 1.9701e-05 - mae: 0.0033 - mape: 344.3959 - val_loss: 8.1682e-06 - val_mse: 8.1682e-06 - val_mae: 0.0019 - val_mape: 615.5291
# Epoch 45/100
# 33/33 [==============================] - 2s 71ms/step - loss: 1.5183e-05 - mse: 1.5183e-05 - mae: 0.0027 - mape: 269.8680 - val_loss: 6.7599e-05 - val_mse: 6.7599e-05 - val_mae: 0.0071 - val_mape: 992.9022
# Epoch 46/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.8014e-05 - mse: 1.8014e-05 - mae: 0.0030 - mape: 297.6722 - val_loss: 2.0049e-05 - val_mse: 2.0049e-05 - val_mae: 0.0039 - val_mape: 981.1785
# Epoch 47/100
# 33/33 [==============================] - 2s 68ms/step - loss: 2.1066e-05 - mse: 2.1066e-05 - mae: 0.0033 - mape: 387.3027 - val_loss: 3.7322e-05 - val_mse: 3.7322e-05 - val_mae: 0.0056 - val_mape: 1116.2301
# Epoch 48/100
# 33/33 [==============================] - 3s 98ms/step - loss: 1.9002e-05 - mse: 1.9002e-05 - mae: 0.0031 - mape: 331.8922 - val_loss: 1.3495e-05 - val_mse: 1.3495e-05 - val_mae: 0.0033 - val_mape: 444.5272
# Epoch 49/100
# 33/33 [==============================] - 3s 78ms/step - loss: 2.0666e-05 - mse: 2.0666e-05 - mae: 0.0033 - mape: 346.3260 - val_loss: 2.7874e-05 - val_mse: 2.7874e-05 - val_mae: 0.0048 - val_mape: 1194.7988
# Epoch 50/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.7078e-05 - mse: 1.7078e-05 - mae: 0.0029 - mape: 317.4413 - val_loss: 1.2478e-05 - val_mse: 1.2478e-05 - val_mae: 0.0027 - val_mape: 403.3285
# Epoch 51/100
# 33/33 [==============================] - 2s 70ms/step - loss: 1.8946e-05 - mse: 1.8946e-05 - mae: 0.0031 - mape: 307.2035 - val_loss: 2.6720e-04 - val_mse: 2.6720e-04 - val_mae: 0.0152 - val_mape: 2401.2605
# Epoch 52/100
# 33/33 [==============================] - 2s 68ms/step - loss: 2.2141e-05 - mse: 2.2141e-05 - mae: 0.0034 - mape: 357.2825 - val_loss: 4.6052e-05 - val_mse: 4.6052e-05 - val_mae: 0.0059 - val_mape: 781.4211
# Epoch 53/100
# 33/33 [==============================] - 3s 94ms/step - loss: 2.0508e-05 - mse: 2.0508e-05 - mae: 0.0032 - mape: 347.0124 - val_loss: 6.8525e-06 - val_mse: 6.8525e-06 - val_mae: 0.0019 - val_mape: 460.3667
# Epoch 54/100
# 33/33 [==============================] - 3s 81ms/step - loss: 1.9203e-05 - mse: 1.9203e-05 - mae: 0.0032 - mape: 354.6987 - val_loss: 1.6850e-05 - val_mse: 1.6850e-05 - val_mae: 0.0031 - val_mape: 512.2333
# Epoch 55/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.9684e-05 - mse: 1.9684e-05 - mae: 0.0033 - mape: 362.2576 - val_loss: 9.5540e-05 - val_mse: 9.5540e-05 - val_mae: 0.0086 - val_mape: 1400.0643
# Epoch 56/100
# 33/33 [==============================] - 2s 71ms/step - loss: 2.1033e-05 - mse: 2.1033e-05 - mae: 0.0033 - mape: 376.8167 - val_loss: 7.0907e-06 - val_mse: 7.0907e-06 - val_mae: 0.0020 - val_mape: 226.2780
# Epoch 57/100
# 33/33 [==============================] - 2s 68ms/step - loss: 2.1250e-05 - mse: 2.1250e-05 - mae: 0.0034 - mape: 367.3665 - val_loss: 3.1928e-05 - val_mse: 3.1928e-05 - val_mae: 0.0049 - val_mape: 839.5421
# Epoch 58/100
# 33/33 [==============================] - 3s 99ms/step - loss: 1.8020e-05 - mse: 1.8020e-05 - mae: 0.0030 - mape: 305.9666 - val_loss: 1.6496e-05 - val_mse: 1.6496e-05 - val_mae: 0.0035 - val_mape: 771.3857
# Epoch 59/100
# 33/33 [==============================] - 2s 75ms/step - loss: 1.7209e-05 - mse: 1.7209e-05 - mae: 0.0029 - mape: 313.6613 - val_loss: 3.5581e-05 - val_mse: 3.5581e-05 - val_mae: 0.0050 - val_mape: 1186.4192
# Epoch 60/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.4025e-05 - mse: 2.4025e-05 - mae: 0.0036 - mape: 416.5236 - val_loss: 2.0063e-05 - val_mse: 2.0063e-05 - val_mae: 0.0036 - val_mape: 722.7655
# Epoch 61/100
# 33/33 [==============================] - 2s 67ms/step - loss: 2.1615e-05 - mse: 2.1615e-05 - mae: 0.0035 - mape: 388.1223 - val_loss: 1.0398e-05 - val_mse: 1.0398e-05 - val_mae: 0.0022 - val_mape: 325.6349
# Epoch 62/100
# 33/33 [==============================] - 2s 70ms/step - loss: 1.7662e-05 - mse: 1.7662e-05 - mae: 0.0031 - mape: 341.5156 - val_loss: 1.4965e-05 - val_mse: 1.4965e-05 - val_mae: 0.0026 - val_mape: 1030.7190
# Epoch 63/100
# 33/33 [==============================] - 3s 88ms/step - loss: 1.8321e-05 - mse: 1.8321e-05 - mae: 0.0030 - mape: 277.6334 - val_loss: 2.2251e-05 - val_mse: 2.2251e-05 - val_mae: 0.0035 - val_mape: 764.7042
# Epoch 64/100
# 33/33 [==============================] - 3s 87ms/step - loss: 2.1630e-05 - mse: 2.1630e-05 - mae: 0.0035 - mape: 382.3162 - val_loss: 1.1490e-05 - val_mse: 1.1490e-05 - val_mae: 0.0029 - val_mape: 345.0023
# Epoch 65/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.0030e-05 - mse: 2.0030e-05 - mae: 0.0033 - mape: 382.4345 - val_loss: 1.1304e-05 - val_mse: 1.1304e-05 - val_mae: 0.0026 - val_mape: 371.7531
# Epoch 66/100
# 33/33 [==============================] - 2s 72ms/step - loss: 1.6231e-05 - mse: 1.6231e-05 - mae: 0.0028 - mape: 283.5917 - val_loss: 1.1158e-05 - val_mse: 1.1158e-05 - val_mae: 0.0029 - val_mape: 329.5048
# Epoch 67/100
# 33/33 [==============================] - 2s 72ms/step - loss: 2.3084e-05 - mse: 2.3084e-05 - mae: 0.0035 - mape: 411.9321 - val_loss: 1.3955e-04 - val_mse: 1.3955e-04 - val_mae: 0.0111 - val_mape: 2632.3369
# Epoch 68/100
# 33/33 [==============================] - 3s 107ms/step - loss: 2.3997e-05 - mse: 2.3997e-05 - mae: 0.0037 - mape: 437.5814 - val_loss: 1.7056e-05 - val_mse: 1.7056e-05 - val_mae: 0.0034 - val_mape: 592.3397
# Epoch 69/100
# 33/33 [==============================] - 3s 75ms/step - loss: 2.0221e-05 - mse: 2.0221e-05 - mae: 0.0033 - mape: 394.2964 - val_loss: 4.0412e-05 - val_mse: 4.0412e-05 - val_mae: 0.0056 - val_mape: 1078.9246
# Epoch 70/100
# 33/33 [==============================] - 2s 70ms/step - loss: 1.7254e-05 - mse: 1.7254e-05 - mae: 0.0029 - mape: 274.6113 - val_loss: 1.0998e-04 - val_mse: 1.0998e-04 - val_mae: 0.0102 - val_mape: 2125.5381
# Epoch 71/100
# 33/33 [==============================] - 2s 67ms/step - loss: 2.0813e-05 - mse: 2.0813e-05 - mae: 0.0034 - mape: 409.9247 - val_loss: 2.5124e-05 - val_mse: 2.5124e-05 - val_mae: 0.0044 - val_mape: 1048.7529
# Epoch 72/100
# 33/33 [==============================] - 2s 70ms/step - loss: 1.5804e-05 - mse: 1.5804e-05 - mae: 0.0027 - mape: 289.6014 - val_loss: 1.2628e-05 - val_mse: 1.2628e-05 - val_mae: 0.0030 - val_mape: 391.8961
# Epoch 73/100
# 33/33 [==============================] - 3s 104ms/step - loss: 2.5065e-05 - mse: 2.5065e-05 - mae: 0.0038 - mape: 435.1022 - val_loss: 6.5086e-05 - val_mse: 6.5086e-05 - val_mae: 0.0072 - val_mape: 1166.4352
# Epoch 74/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.3913e-05 - mse: 2.3913e-05 - mae: 0.0037 - mape: 419.4376 - val_loss: 5.7516e-05 - val_mse: 5.7516e-05 - val_mae: 0.0060 - val_mape: 1959.9703
# Epoch 75/100
# 33/33 [==============================] - 2s 68ms/step - loss: 2.1263e-05 - mse: 2.1263e-05 - mae: 0.0032 - mape: 326.8864 - val_loss: 7.9384e-06 - val_mse: 7.9384e-06 - val_mae: 0.0022 - val_mape: 269.2068
# Epoch 76/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.4216e-05 - mse: 2.4216e-05 - mae: 0.0035 - mape: 385.0056 - val_loss: 8.4376e-06 - val_mse: 8.4376e-06 - val_mae: 0.0023 - val_mape: 469.6490
# Epoch 77/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.1350e-05 - mse: 2.1350e-05 - mae: 0.0035 - mape: 444.0680 - val_loss: 1.3952e-04 - val_mse: 1.3952e-04 - val_mae: 0.0116 - val_mape: 2140.0840
# Epoch 78/100
# 33/33 [==============================] - 4s 109ms/step - loss: 2.1022e-05 - mse: 2.1022e-05 - mae: 0.0033 - mape: 398.2490 - val_loss: 6.9627e-06 - val_mse: 6.9627e-06 - val_mae: 0.0021 - val_mape: 359.6755
# Epoch 79/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.9568e-05 - mse: 1.9568e-05 - mae: 0.0032 - mape: 368.4382 - val_loss: 9.9956e-05 - val_mse: 9.9956e-05 - val_mae: 0.0098 - val_mape: 2081.0371
# 21/21 [==============================] - 1s 7ms/step
# 9/9 [==============================] - 0s 7ms/step
# [I 2023-03-06 12:18:48,968] Trial 1 finished with value: 1.95676493603969e-05 and parameters: {'hidden_units': 97, 'activation': 'relu', 'learning_rate': 0.037624889033322007}. Best is trial 0 with value: 1.760158374963794e-05.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 33/33 [==============================] - 11s 102ms/step - loss: 0.0190 - mse: 0.0190 - mae: 0.0772 - mape: 11609.5566 - val_loss: 6.2437e-04 - val_mse: 6.2437e-04 - val_mae: 0.0246 - val_mape: 4472.9819
# Epoch 2/100
# 33/33 [==============================] - 2s 65ms/step - loss: 1.7957e-04 - mse: 1.7957e-04 - mae: 0.0101 - mape: 1276.0481 - val_loss: 2.6897e-05 - val_mse: 2.6897e-05 - val_mae: 0.0040 - val_mape: 859.7402
# Epoch 3/100
# 33/33 [==============================] - 2s 66ms/step - loss: 5.9382e-05 - mse: 5.9382e-05 - mae: 0.0059 - mape: 759.5158 - val_loss: 4.8488e-05 - val_mse: 4.8488e-05 - val_mae: 0.0060 - val_mape: 1266.7958
# Epoch 4/100
# 33/33 [==============================] - 2s 70ms/step - loss: 4.3724e-05 - mse: 4.3724e-05 - mae: 0.0050 - mape: 590.6613 - val_loss: 7.9551e-06 - val_mse: 7.9551e-06 - val_mae: 0.0019 - val_mape: 527.8049
# Epoch 5/100
# 33/33 [==============================] - 3s 102ms/step - loss: 3.9401e-05 - mse: 3.9401e-05 - mae: 0.0048 - mape: 567.5037 - val_loss: 1.8751e-05 - val_mse: 1.8751e-05 - val_mae: 0.0034 - val_mape: 1024.6426
# Epoch 6/100
# 33/33 [==============================] - 2s 70ms/step - loss: 3.8056e-05 - mse: 3.8056e-05 - mae: 0.0047 - mape: 563.6332 - val_loss: 4.1018e-05 - val_mse: 4.1018e-05 - val_mae: 0.0057 - val_mape: 675.0234
# Epoch 7/100
# 33/33 [==============================] - 2s 66ms/step - loss: 7.0503e-05 - mse: 7.0503e-05 - mae: 0.0065 - mape: 796.1685 - val_loss: 2.0024e-05 - val_mse: 2.0024e-05 - val_mae: 0.0040 - val_mape: 381.3886
# Epoch 8/100
# 33/33 [==============================] - 2s 66ms/step - loss: 3.2727e-05 - mse: 3.2727e-05 - mae: 0.0043 - mape: 479.9839 - val_loss: 6.0301e-05 - val_mse: 6.0301e-05 - val_mae: 0.0065 - val_mape: 579.6265
# Epoch 9/100
# 33/33 [==============================] - 2s 67ms/step - loss: 3.3917e-05 - mse: 3.3917e-05 - mae: 0.0043 - mape: 482.8967 - val_loss: 3.0060e-05 - val_mse: 3.0060e-05 - val_mae: 0.0049 - val_mape: 565.7631
# Epoch 10/100
# 33/33 [==============================] - 3s 93ms/step - loss: 3.9767e-05 - mse: 3.9767e-05 - mae: 0.0047 - mape: 560.6852 - val_loss: 1.1884e-04 - val_mse: 1.1884e-04 - val_mae: 0.0089 - val_mape: 2626.8301
# Epoch 11/100
# 33/33 [==============================] - 3s 78ms/step - loss: 6.0562e-05 - mse: 6.0562e-05 - mae: 0.0060 - mape: 816.9874 - val_loss: 2.7539e-05 - val_mse: 2.7539e-05 - val_mae: 0.0045 - val_mape: 602.0732
# Epoch 12/100
# 33/33 [==============================] - 2s 69ms/step - loss: 5.6266e-05 - mse: 5.6266e-05 - mae: 0.0058 - mape: 680.0159 - val_loss: 3.7115e-05 - val_mse: 3.7115e-05 - val_mae: 0.0051 - val_mape: 1088.6152
# Epoch 13/100
# 33/33 [==============================] - 2s 68ms/step - loss: 5.8798e-05 - mse: 5.8798e-05 - mae: 0.0061 - mape: 755.9728 - val_loss: 3.8938e-05 - val_mse: 3.8938e-05 - val_mae: 0.0047 - val_mape: 1466.3689
# Epoch 14/100
# 33/33 [==============================] - 2s 65ms/step - loss: 4.4238e-05 - mse: 4.4238e-05 - mae: 0.0051 - mape: 658.1983 - val_loss: 2.0277e-05 - val_mse: 2.0277e-05 - val_mae: 0.0036 - val_mape: 992.1643
# Epoch 15/100
# 33/33 [==============================] - 3s 85ms/step - loss: 2.5064e-05 - mse: 2.5064e-05 - mae: 0.0037 - mape: 384.3518 - val_loss: 1.7591e-05 - val_mse: 1.7591e-05 - val_mae: 0.0031 - val_mape: 668.3729
# Epoch 16/100
# 33/33 [==============================] - 3s 89ms/step - loss: 2.9417e-05 - mse: 2.9417e-05 - mae: 0.0040 - mape: 434.3002 - val_loss: 1.0780e-05 - val_mse: 1.0780e-05 - val_mae: 0.0022 - val_mape: 734.4662
# Epoch 17/100
# 33/33 [==============================] - 2s 66ms/step - loss: 3.5468e-05 - mse: 3.5468e-05 - mae: 0.0046 - mape: 510.3963 - val_loss: 5.9275e-06 - val_mse: 5.9275e-06 - val_mae: 0.0016 - val_mape: 476.0461
# Epoch 18/100
# 33/33 [==============================] - 2s 68ms/step - loss: 3.0695e-05 - mse: 3.0695e-05 - mae: 0.0042 - mape: 497.4318 - val_loss: 1.1435e-05 - val_mse: 1.1435e-05 - val_mae: 0.0025 - val_mape: 710.6625
# Epoch 19/100
# 33/33 [==============================] - 2s 66ms/step - loss: 2.9035e-05 - mse: 2.9035e-05 - mae: 0.0041 - mape: 502.6624 - val_loss: 3.1054e-05 - val_mse: 3.1054e-05 - val_mae: 0.0043 - val_mape: 815.0774
# Epoch 20/100
# 33/33 [==============================] - 3s 80ms/step - loss: 3.1606e-05 - mse: 3.1606e-05 - mae: 0.0042 - mape: 465.1435 - val_loss: 4.3326e-05 - val_mse: 4.3326e-05 - val_mae: 0.0060 - val_mape: 1161.6324
# Epoch 21/100
# 33/33 [==============================] - 3s 98ms/step - loss: 2.8461e-05 - mse: 2.8461e-05 - mae: 0.0040 - mape: 487.8421 - val_loss: 2.1322e-05 - val_mse: 2.1322e-05 - val_mae: 0.0037 - val_mape: 913.9734
# Epoch 22/100
# 33/33 [==============================] - 2s 68ms/step - loss: 3.0496e-05 - mse: 3.0496e-05 - mae: 0.0042 - mape: 459.7563 - val_loss: 9.4406e-06 - val_mse: 9.4406e-06 - val_mae: 0.0023 - val_mape: 455.6964
# Epoch 23/100
# 33/33 [==============================] - 2s 70ms/step - loss: 2.5600e-05 - mse: 2.5600e-05 - mae: 0.0037 - mape: 432.8323 - val_loss: 1.2877e-05 - val_mse: 1.2877e-05 - val_mae: 0.0028 - val_mape: 597.5843
# Epoch 24/100
# 33/33 [==============================] - 2s 70ms/step - loss: 3.3735e-05 - mse: 3.3735e-05 - mae: 0.0044 - mape: 504.8296 - val_loss: 2.2913e-05 - val_mse: 2.2913e-05 - val_mae: 0.0038 - val_mape: 1136.9866
# Epoch 25/100
# 33/33 [==============================] - 3s 79ms/step - loss: 3.8509e-05 - mse: 3.8509e-05 - mae: 0.0048 - mape: 572.5195 - val_loss: 3.7919e-05 - val_mse: 3.7919e-05 - val_mae: 0.0051 - val_mape: 1288.9613
# Epoch 26/100
# 33/33 [==============================] - 3s 92ms/step - loss: 4.0330e-05 - mse: 4.0330e-05 - mae: 0.0050 - mape: 659.7127 - val_loss: 1.3024e-05 - val_mse: 1.3024e-05 - val_mae: 0.0027 - val_mape: 405.5687
# Epoch 27/100
# 33/33 [==============================] - 2s 65ms/step - loss: 3.2196e-05 - mse: 3.2196e-05 - mae: 0.0043 - mape: 524.2639 - val_loss: 1.8051e-05 - val_mse: 1.8051e-05 - val_mae: 0.0031 - val_mape: 1031.7145
# Epoch 28/100
# 33/33 [==============================] - 2s 67ms/step - loss: 2.4744e-05 - mse: 2.4744e-05 - mae: 0.0037 - mape: 379.6454 - val_loss: 8.7255e-06 - val_mse: 8.7255e-06 - val_mae: 0.0019 - val_mape: 678.4358
# Epoch 29/100
# 33/33 [==============================] - 2s 65ms/step - loss: 2.3230e-05 - mse: 2.3230e-05 - mae: 0.0035 - mape: 374.0268 - val_loss: 5.7071e-06 - val_mse: 5.7071e-06 - val_mae: 0.0016 - val_mape: 387.5559
# Epoch 30/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.3249e-05 - mse: 2.3249e-05 - mae: 0.0034 - mape: 359.4066 - val_loss: 1.6998e-05 - val_mse: 1.6998e-05 - val_mae: 0.0035 - val_mape: 523.9299
# Epoch 31/100
# 33/33 [==============================] - 3s 103ms/step - loss: 3.0272e-05 - mse: 3.0272e-05 - mae: 0.0041 - mape: 478.7684 - val_loss: 8.0213e-06 - val_mse: 8.0213e-06 - val_mae: 0.0019 - val_mape: 613.0930
# Epoch 32/100
# 33/33 [==============================] - 2s 66ms/step - loss: 2.9007e-05 - mse: 2.9007e-05 - mae: 0.0040 - mape: 478.6317 - val_loss: 1.5532e-05 - val_mse: 1.5532e-05 - val_mae: 0.0029 - val_mape: 930.7246
# Epoch 33/100
# 33/33 [==============================] - 2s 69ms/step - loss: 3.3355e-05 - mse: 3.3355e-05 - mae: 0.0043 - mape: 489.3152 - val_loss: 1.6376e-05 - val_mse: 1.6376e-05 - val_mae: 0.0030 - val_mape: 626.7922
# ...
# Epoch 90/100
# 33/33 [==============================] - 3s 82ms/step - loss: 1.2143e-05 - mse: 1.2143e-05 - mae: 0.0024 - mape: 232.8438 - val_loss: 6.5093e-06 - val_mse: 6.5093e-06 - val_mae: 0.0017 - val_mape: 413.2156
# Epoch 91/100
# 33/33 [==============================] - 3s 91ms/step - loss: 1.2486e-05 - mse: 1.2486e-05 - mae: 0.0024 - mape: 246.4896 - val_loss: 4.7097e-06 - val_mse: 4.7097e-06 - val_mae: 0.0015 - val_mape: 316.6384
# Epoch 92/100
# 33/33 [==============================] - 2s 69ms/step - loss: 1.1782e-05 - mse: 1.1782e-05 - mae: 0.0022 - mape: 215.3079 - val_loss: 1.2663e-05 - val_mse: 1.2663e-05 - val_mae: 0.0029 - val_mape: 715.9158
# Epoch 93/100
# 33/33 [==============================] - 2s 71ms/step - loss: 1.3046e-05 - mse: 1.3046e-05 - mae: 0.0025 - mape: 264.8712 - val_loss: 1.1212e-05 - val_mse: 1.1212e-05 - val_mae: 0.0030 - val_mape: 362.9549
# Epoch 94/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.3273e-05 - mse: 1.3273e-05 - mae: 0.0025 - mape: 240.2729 - val_loss: 4.7347e-06 - val_mse: 4.7347e-06 - val_mae: 0.0015 - val_mape: 239.3242
# Epoch 95/100
# 33/33 [==============================] - 3s 84ms/step - loss: 1.2416e-05 - mse: 1.2416e-05 - mae: 0.0024 - mape: 239.9587 - val_loss: 7.9066e-06 - val_mse: 7.9066e-06 - val_mae: 0.0022 - val_mape: 237.2240
# Epoch 96/100
# 33/33 [==============================] - 3s 92ms/step - loss: 1.0807e-05 - mse: 1.0807e-05 - mae: 0.0022 - mape: 205.6855 - val_loss: 4.4530e-06 - val_mse: 4.4530e-06 - val_mae: 0.0013 - val_mape: 347.2575
# Epoch 97/100
# 33/33 [==============================] - 2s 68ms/step - loss: 1.2701e-05 - mse: 1.2701e-05 - mae: 0.0024 - mape: 258.4901 - val_loss: 5.3144e-06 - val_mse: 5.3144e-06 - val_mae: 0.0015 - val_mape: 446.7614
# Epoch 98/100
# 33/33 [==============================] - 2s 71ms/step - loss: 1.2380e-05 - mse: 1.2380e-05 - mae: 0.0024 - mape: 235.1139 - val_loss: 6.5427e-06 - val_mse: 6.5427e-06 - val_mae: 0.0018 - val_mape: 218.7851
# Epoch 99/100
# 33/33 [==============================] - 2s 71ms/step - loss: 1.3273e-05 - mse: 1.3273e-05 - mae: 0.0025 - mape: 258.6755 - val_loss: 8.3525e-06 - val_mse: 8.3525e-06 - val_mae: 0.0021 - val_mape: 452.7758
# Epoch 100/100
# 33/33 [==============================] - 3s 86ms/step - loss: 1.1011e-05 - mse: 1.1011e-05 - mae: 0.0021 - mape: 200.2420 - val_loss: 1.3773e-05 - val_mse: 1.3773e-05 - val_mae: 0.0030 - val_mape: 859.3593
# 21/21 [==============================] - 1s 10ms/step
# 9/9 [==============================] - 0s 9ms/step
# [I 2023-03-06 12:32:02,979] Trial 4 finished with value: 1.10111277535907e-05 and parameters: {'hidden_units': 39, 'activation': 'tanh', 'learning_rate': 0.004229321071804456}. Best is trial 4 with value: 1.10111277535907e-05.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 33/33 [==============================] - 10s 94ms/step - loss: 0.0502 - mse: 0.0502 - mae: 0.1256 - mape: 18240.0625 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0359 - val_mape: 4436.7744
# Epoch 2/100
# 33/33 [==============================] - 3s 91ms/step - loss: 5.1863e-04 - mse: 5.1863e-04 - mae: 0.0174 - mape: 2213.7393 - val_loss: 9.8906e-05 - val_mse: 9.8905e-05 - val_mae: 0.0089 - val_mape: 2054.0002
# Epoch 3/100
# 33/33 [==============================] - 2s 66ms/step - loss: 1.0085e-04 - mse: 1.0085e-04 - mae: 0.0079 - mape: 1116.9531 - val_loss: 1.2497e-05 - val_mse: 1.2497e-05 - val_mae: 0.0029 - val_mape: 313.8097
# Epoch 4/100
# 33/33 [==============================] - 2s 66ms/step - loss: 6.6810e-05 - mse: 6.6810e-05 - mae: 0.0063 - mape: 824.3115 - val_loss: 1.5747e-05 - val_mse: 1.5747e-05 - val_mae: 0.0033 - val_mape: 424.8109
# Epoch 5/100
# 33/33 [==============================] - 2s 67ms/step - loss: 6.3279e-05 - mse: 6.3279e-05 - mae: 0.0062 - mape: 795.9838 - val_loss: 3.7951e-05 - val_mse: 3.7951e-05 - val_mae: 0.0047 - val_mape: 924.3566
# Epoch 6/100
# 33/33 [==============================] - 2s 75ms/step - loss: 6.3637e-05 - mse: 6.3637e-05 - mae: 0.0062 - mape: 803.9641 - val_loss: 2.6910e-05 - val_mse: 2.6910e-05 - val_mae: 0.0039 - val_mape: 670.5098
# Epoch 7/100
# 33/33 [==============================] - 3s 101ms/step - loss: 5.7302e-05 - mse: 5.7302e-05 - mae: 0.0059 - mape: 742.5356 - val_loss: 1.2690e-05 - val_mse: 1.2690e-05 - val_mae: 0.0028 - val_mape: 565.3846
# Epoch 8/100
# 33/33 [==============================] - 2s 70ms/step - loss: 4.0324e-05 - mse: 4.0324e-05 - mae: 0.0049 - mape: 590.1158 - val_loss: 5.1931e-05 - val_mse: 5.1931e-05 - val_mae: 0.0054 - val_mape: 1759.5715
# Epoch 9/100
# 33/33 [==============================] - 2s 67ms/step - loss: 4.8611e-05 - mse: 4.8611e-05 - mae: 0.0054 - mape: 709.7375 - val_loss: 9.9468e-06 - val_mse: 9.9468e-06 - val_mae: 0.0026 - val_mape: 321.2831
# Epoch 10/100
# 33/33 [==============================] - 2s 69ms/step - loss: 4.6314e-05 - mse: 4.6314e-05 - mae: 0.0053 - mape: 620.2490 - val_loss: 6.5589e-05 - val_mse: 6.5589e-05 - val_mae: 0.0073 - val_mape: 1668.7814
# Epoch 11/100
# 33/33 [==============================] - 2s 68ms/step - loss: 7.5527e-05 - mse: 7.5527e-05 - mae: 0.0068 - mape: 869.3821 - val_loss: 9.3700e-05 - val_mse: 9.3700e-05 - val_mae: 0.0081 - val_mape: 1310.6798
# Epoch 12/100
# 33/33 [==============================] - 3s 103ms/step - loss: 4.8622e-05 - mse: 4.8622e-05 - mae: 0.0055 - mape: 711.9860 - val_loss: 5.5545e-05 - val_mse: 5.5545e-05 - val_mae: 0.0068 - val_mape: 1338.8103
# Epoch 13/100
# 33/33 [==============================] - 2s 65ms/step - loss: 5.3929e-05 - mse: 5.3929e-05 - mae: 0.0057 - mape: 750.0795 - val_loss: 4.1322e-05 - val_mse: 4.1322e-05 - val_mae: 0.0054 - val_mape: 858.1340
# Epoch 14/100
# 33/33 [==============================] - 2s 70ms/step - loss: 3.3100e-05 - mse: 3.3100e-05 - mae: 0.0044 - mape: 524.0889 - val_loss: 1.8838e-05 - val_mse: 1.8838e-05 - val_mae: 0.0032 - val_mape: 1049.5427
# Epoch 15/100
# 33/33 [==============================] - 2s 72ms/step - loss: 5.6241e-05 - mse: 5.6241e-05 - mae: 0.0058 - mape: 742.5150 - val_loss: 2.9866e-05 - val_mse: 2.9866e-05 - val_mae: 0.0039 - val_mape: 517.5599
# Epoch 16/100
# 33/33 [==============================] - 2s 72ms/step - loss: 5.2659e-05 - mse: 5.2659e-05 - mae: 0.0055 - mape: 698.1269 - val_loss: 1.2210e-05 - val_mse: 1.2210e-05 - val_mae: 0.0027 - val_mape: 706.9391
# Epoch 17/100
# 33/33 [==============================] - 4s 106ms/step - loss: 5.8254e-05 - mse: 5.8254e-05 - mae: 0.0061 - mape: 825.2553 - val_loss: 4.1631e-05 - val_mse: 4.1631e-05 - val_mae: 0.0051 - val_mape: 998.6527
# Epoch 18/100
# 33/33 [==============================] - 2s 70ms/step - loss: 5.8006e-05 - mse: 5.8006e-05 - mae: 0.0061 - mape: 805.1554 - val_loss: 3.7802e-05 - val_mse: 3.7802e-05 - val_mae: 0.0055 - val_mape: 1129.5562
# Epoch 19/100
# 33/33 [==============================] - 2s 69ms/step - loss: 4.9074e-05 - mse: 4.9074e-05 - mae: 0.0054 - mape: 653.0477 - val_loss: 3.7085e-05 - val_mse: 3.7085e-05 - val_mae: 0.0052 - val_mape: 1025.3109
# Epoch 20/100
# 33/33 [==============================] - 2s 68ms/step - loss: 2.9256e-05 - mse: 2.9256e-05 - mae: 0.0041 - mape: 490.3004 - val_loss: 6.8453e-05 - val_mse: 6.8453e-05 - val_mae: 0.0072 - val_mape: 863.3317
# Epoch 21/100
# 33/33 [==============================] - 2s 70ms/step - loss: 4.5649e-05 - mse: 4.5649e-05 - mae: 0.0054 - mape: 653.8641 - val_loss: 1.5170e-05 - val_mse: 1.5170e-05 - val_mae: 0.0034 - val_mape: 378.5688
# Epoch 22/100
# 33/33 [==============================] - 4s 109ms/step - loss: 4.2736e-05 - mse: 4.2736e-05 - mae: 0.0050 - mape: 632.3776 - val_loss: 1.0548e-05 - val_mse: 1.0548e-05 - val_mae: 0.0024 - val_mape: 741.9393
# Epoch 23/100
# 33/33 [==============================] - 2s 66ms/step - loss: 4.0249e-05 - mse: 4.0249e-05 - mae: 0.0048 - mape: 534.7400 - val_loss: 1.4735e-05 - val_mse: 1.4735e-05 - val_mae: 0.0032 - val_mape: 480.0547
# Epoch 24/100
# 33/33 [==============================] - 2s 69ms/step - loss: 4.5936e-05 - mse: 4.5936e-05 - mae: 0.0054 - mape: 699.3188 - val_loss: 3.1533e-05 - val_mse: 3.1533e-05 - val_mae: 0.0052 - val_mape: 1188.4092
# Epoch 25/100
# 33/33 [==============================] - 2s 68ms/step - loss: 3.5074e-05 - mse: 3.5074e-05 - mae: 0.0045 - mape: 543.1574 - val_loss: 2.5063e-05 - val_mse: 2.5063e-05 - val_mae: 0.0044 - val_mape: 912.2733
# Epoch 26/100
# 33/33 [==============================] - 2s 73ms/step - loss: 3.1840e-05 - mse: 3.1840e-05 - mae: 0.0043 - mape: 534.7372 - val_loss: 1.2984e-05 - val_mse: 1.2984e-05 - val_mae: 0.0030 - val_mape: 434.7316
# Epoch 27/100
# 33/33 [==============================] - 4s 109ms/step - loss: 6.3123e-05 - mse: 6.3123e-05 - mae: 0.0064 - mape: 844.5402 - val_loss: 6.1456e-06 - val_mse: 6.1456e-06 - val_mae: 0.0018 - val_mape: 348.6098
# Epoch 28/100
# 33/33 [==============================] - 2s 70ms/step - loss: 2.9834e-05 - mse: 2.9834e-05 - mae: 0.0041 - mape: 511.0172 - val_loss: 2.9590e-05 - val_mse: 2.9590e-05 - val_mae: 0.0046 - val_mape: 577.6588
# Epoch 29/100
# 33/33 [==============================] - 2s 69ms/step - loss: 3.6005e-05 - mse: 3.6005e-05 - mae: 0.0046 - mape: 583.4828 - val_loss: 2.2337e-05 - val_mse: 2.2337e-05 - val_mae: 0.0044 - val_mape: 522.9368
# Epoch 30/100
# 33/33 [==============================] - 2s 70ms/step - loss: 4.0643e-05 - mse: 4.0643e-05 - mae: 0.0050 - mape: 622.8989 - val_loss: 1.6240e-04 - val_mse: 1.6240e-04 - val_mae: 0.0125 - val_mape: 2479.8926
# Epoch 31/100
# 33/33 [==============================] - 2s 75ms/step - loss: 7.3444e-05 - mse: 7.3444e-05 - mae: 0.0070 - mape: 1005.2019 - val_loss: 2.7039e-05 - val_mse: 2.7039e-05 - val_mae: 0.0049 - val_mape: 672.5506
# Epoch 32/100
# 33/33 [==============================] - 3s 101ms/step - loss: 4.8742e-05 - mse: 4.8742e-05 - mae: 0.0056 - mape: 688.4075 - val_loss: 8.2462e-05 - val_mse: 8.2462e-05 - val_mae: 0.0086 - val_mape: 1858.4218
# Epoch 33/100
# 33/33 [==============================] - 2s 67ms/step - loss: 3.6944e-05 - mse: 3.6944e-05 - mae: 0.0047 - mape: 579.8708 - val_loss: 3.7283e-05 - val_mse: 3.7283e-05 - val_mae: 0.0054 - val_mape: 1387.2611
# Epoch 34/100
# 33/33 [==============================] - 2s 68ms/step - loss: 2.8753e-05 - mse: 2.8753e-05 - mae: 0.0040 - mape: 419.3231 - val_loss: 1.4134e-05 - val_mse: 1.4134e-05 - val_mae: 0.0028 - val_mape: 502.2701
# Epoch 35/100
# 33/33 [==============================] - 2s 67ms/step - loss: 2.7710e-05 - mse: 2.7710e-05 - mae: 0.0039 - mape: 455.8130 - val_loss: 9.8823e-06 - val_mse: 9.8823e-06 - val_mae: 0.0023 - val_mape: 645.4473
# Epoch 36/100
# 33/33 [==============================] - 2s 72ms/step - loss: 3.1488e-05 - mse: 3.1488e-05 - mae: 0.0043 - mape: 537.1559 - val_loss: 3.4725e-05 - val_mse: 3.4725e-05 - val_mae: 0.0051 - val_mape: 1185.5067
# Epoch 37/100
# 33/33 [==============================] - 3s 102ms/step - loss: 4.3061e-05 - mse: 4.3061e-05 - mae: 0.0052 - mape: 660.5966 - val_loss: 1.3983e-05 - val_mse: 1.3983e-05 - val_mae: 0.0030 - val_mape: 505.1645
# Epoch 38/100
# 33/33 [==============================] - 2s 65ms/step - loss: 2.2132e-05 - mse: 2.2132e-05 - mae: 0.0034 - mape: 361.2210 - val_loss: 6.6262e-06 - val_mse: 6.6262e-06 - val_mae: 0.0020 - val_mape: 246.6499
# Epoch 39/100
# 33/33 [==============================] - 2s 70ms/step - loss: 3.1388e-05 - mse: 3.1388e-05 - mae: 0.0042 - mape: 446.1483 - val_loss: 3.5986e-05 - val_mse: 3.5986e-05 - val_mae: 0.0051 - val_mape: 1415.2598
# Epoch 40/100
# 33/33 [==============================] - 2s 70ms/step - loss: 3.3857e-05 - mse: 3.3857e-05 - mae: 0.0045 - mape: 546.5017 - val_loss: 1.3459e-05 - val_mse: 1.3459e-05 - val_mae: 0.0031 - val_mape: 451.9049
# Epoch 41/100
# 33/33 [==============================] - 2s 71ms/step - loss: 3.4580e-05 - mse: 3.4580e-05 - mae: 0.0045 - mape: 516.2849 - val_loss: 4.2815e-05 - val_mse: 4.2815e-05 - val_mae: 0.0053 - val_mape: 877.5830
# Epoch 42/100
# 33/33 [==============================] - 3s 101ms/step - loss: 5.2971e-05 - mse: 5.2971e-05 - mae: 0.0058 - mape: 784.4916 - val_loss: 3.3707e-05 - val_mse: 3.3707e-05 - val_mae: 0.0052 - val_mape: 597.9769
# Epoch 43/100
# 33/33 [==============================] - 2s 68ms/step - loss: 2.8575e-05 - mse: 2.8575e-05 - mae: 0.0040 - mape: 455.0509 - val_loss: 8.8243e-06 - val_mse: 8.8243e-06 - val_mae: 0.0021 - val_mape: 642.6326
# Epoch 44/100
# 33/33 [==============================] - 2s 68ms/step - loss: 2.5721e-05 - mse: 2.5721e-05 - mae: 0.0038 - mape: 433.6962 - val_loss: 7.7351e-06 - val_mse: 7.7351e-06 - val_mae: 0.0019 - val_mape: 543.2845
# Epoch 45/100
# 33/33 [==============================] - 2s 67ms/step - loss: 4.2830e-05 - mse: 4.2830e-05 - mae: 0.0050 - mape: 586.1617 - val_loss: 5.9702e-05 - val_mse: 5.9702e-05 - val_mae: 0.0074 - val_mape: 1690.9224
# Epoch 46/100
# 33/33 [==============================] - 2s 71ms/step - loss: 2.7877e-05 - mse: 2.7877e-05 - mae: 0.0039 - mape: 429.8100 - val_loss: 1.0355e-05 - val_mse: 1.0355e-05 - val_mae: 0.0024 - val_mape: 550.6562
# Epoch 47/100
# 33/33 [==============================] - 4s 107ms/step - loss: 3.0428e-05 - mse: 3.0428e-05 - mae: 0.0042 - mape: 513.4098 - val_loss: 3.1461e-05 - val_mse: 3.1461e-05 - val_mae: 0.0045 - val_mape: 973.4938
# Epoch 48/100
# 33/33 [==============================] - 2s 68ms/step - loss: 3.3783e-05 - mse: 3.3783e-05 - mae: 0.0043 - mape: 524.5018 - val_loss: 7.4600e-06 - val_mse: 7.4600e-06 - val_mae: 0.0021 - val_mape: 346.2649
# Epoch 49/100
# 33/33 [==============================] - 2s 68ms/step - loss: 4.0549e-05 - mse: 4.0549e-05 - mae: 0.0050 - mape: 569.5087 - val_loss: 1.7402e-05 - val_mse: 1.7402e-05 - val_mae: 0.0036 - val_mape: 492.3206
# Epoch 50/100
# 33/33 [==============================] - 2s 67ms/step - loss: 3.0157e-05 - mse: 3.0157e-05 - mae: 0.0042 - mape: 512.4902 - val_loss: 1.6367e-05 - val_mse: 1.6367e-05 - val_mae: 0.0036 - val_mape: 419.6418
# Epoch 51/100
# 33/33 [==============================] - 2s 65ms/step - loss: 3.7616e-05 - mse: 3.7616e-05 - mae: 0.0048 - mape: 608.4111 - val_loss: 7.5305e-06 - val_mse: 7.5305e-06 - val_mae: 0.0020 - val_mape: 361.6629
# Epoch 52/100
# 33/33 [==============================] - 4s 110ms/step - loss: 2.1958e-05 - mse: 2.1958e-05 - mae: 0.0033 - mape: 329.2752 - val_loss: 1.5947e-05 - val_mse: 1.5947e-05 - val_mae: 0.0031 - val_mape: 871.7669
# Epoch 53/100
# 33/33 [==============================] - 2s 67ms/step - loss: 2.2605e-05 - mse: 2.2605e-05 - mae: 0.0034 - mape: 379.3304 - val_loss: 1.5373e-05 - val_mse: 1.5373e-05 - val_mae: 0.0031 - val_mape: 702.5648
# Epoch 54/100
# 33/33 [==============================] - 2s 67ms/step - loss: 2.3004e-05 - mse: 2.3004e-05 - mae: 0.0034 - mape: 355.1458 - val_loss: 6.9042e-06 - val_mse: 6.9042e-06 - val_mae: 0.0020 - val_mape: 219.0698
# Epoch 55/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.0385e-05 - mse: 2.0385e-05 - mae: 0.0032 - mape: 313.9433 - val_loss: 8.1021e-06 - val_mse: 8.1021e-06 - val_mae: 0.0022 - val_mape: 459.3452
# Epoch 56/100
# 33/33 [==============================] - 2s 69ms/step - loss: 2.3513e-05 - mse: 2.3513e-05 - mae: 0.0035 - mape: 391.3610 - val_loss: 5.8201e-06 - val_mse: 5.8201e-06 - val_mae: 0.0016 - val_mape: 410.9884
# Epoch 57/100
# 33/33 [==============================] - 4s 109ms/step - loss: 2.3698e-05 - mse: 2.3698e-05 - mae: 0.0035 - mape: 372.4279 - val_loss: 1.0557e-05 - val_mse: 1.0557e-05 - val_mae: 0.0024 - val_mape: 423.1552
# Epoch 58/100
# 33/33 [==============================] - 2s 70ms/step - loss: 2.2413e-05 - mse: 2.2413e-05 - mae: 0.0035 - mape: 353.7564 - val_loss: 1.1620e-05 - val_mse: 1.1620e-05 - val_mae: 0.0026 - val_mape: 574.0460
# Epoch 59/100
# 29/33 [=========================>....] - ETA: 0s - loss: 2.2472e-05 - mse: 2.2472e-05 - mae: 0.0035 - mape: 418.8548

# %%
optuna.visualization.plot_param_importances(study)

# %%
optuna.visualization.plot_contour(study, params=["hidden_units", "activation", "learning_rate"])

# %%
optuna.visualization.matplotlib.plot_parallel_coordinate(study, params=["hidden_units", "activation", "learning_rate"])

# %%
plt.figure(figsize=(10, 4))
plt.plot(train_loss, 'k', zorder=2, label='Train')
plt.plot(valid_loss, 'r', zorder=2, label='Validation')
plt.legend(loc='upper right', fancybox=True, shadow=False, ncol=1)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.yscale("log") 
plt.grid(linestyle = '--', linewidth = 0.5, zorder=0)
plt.show()
# plt.savefig('Loss.pdf')

# %% [markdown]
# # Model Evaluation 2: Optimized Seq2Seq-LSTM with Attention

# %% [markdown]
# ## Model evaluation

# %%
# Number of hidden neurons defined by the optimizer
n_hidden = 78

input_train = Input(shape=(X_input_train.shape[1], X_input_train.shape[2]-1))
output_train = Input(shape=(X_output_train.shape[1], X_output_train.shape[2]-1))

encoder_stack_h, encoder_last_h, encoder_last_c = LSTM(n_hidden, activation='relu', dropout=0.2, recurrent_dropout=0.2, return_state=True, return_sequences=True)(input_train)
encoder_last_h = BatchNormalization(momentum=0.6)(encoder_last_h)
encoder_last_c = BatchNormalization(momentum=0.6)(encoder_last_c)

# Activation function defined by the optimizer
decoder_input = RepeatVector(output_train.shape[1])(encoder_last_h)
decoder_stack_h = LSTM(n_hidden, activation='elu', dropout=0.2, recurrent_dropout=0.2, return_state=False, return_sequences=True)(decoder_input, initial_state=[encoder_last_h, encoder_last_c])

attention = dot([decoder_stack_h, encoder_stack_h], axes=[2, 2])
attention = Activation('softmax')(attention)
context = dot([attention, encoder_stack_h], axes=[2,1])
context = BatchNormalization(momentum=0.6)(context)

decoder_combined_context = concatenate([context, decoder_stack_h])
out = TimeDistributed(Dense(output_train.shape[2]))(decoder_combined_context)
model = Model(inputs=input_train, outputs=out)

# Learning rate defined by the optimizer
opt = Adam(lr=0.013629063355056946, clipnorm=1)
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mse', 'mae', 'mape'])

# Evaluate the time for training the model
inicio = time.time()

# EWT considered
TOTAL = 3

# To save values for statistics
MSE=[]
MAE=[]
MAPE=[]

for i in range(statistics):
  es = EarlyStopping(monitor='val_loss', mode='min', patience=50)
  history = model.fit(X_input_train[:, :, :TOTAL], X_output_train[:, :, :TOTAL], validation_split=0.2, epochs=epc, verbose=1, callbacks=[es], batch_size=batch_siz)
  train_loss = history.history['loss']
  valid_loss = history.history['val_loss']
  mse = history.history['mse']
  mae = history.history['mae']
  mape = history.history['mape']
  model.save('model_forecasting_seq2seq.h5')

  train_pred_detrend = model.predict(X_input_train[:, :, :TOTAL])
  test_pred_detrend = model.predict(X_input_test[:, :, :TOTAL])
  train_true_detrend = X_output_train[:, :, :TOTAL]
  test_true_detrend = X_output_test[:, :, :TOTAL]
  data_final = dict()

  print(f'Simulation: {i+1}')
  MSE.append(mse[len(mse)-1])
  MAE.append(mae[len(mse)-1])
  MAPE.append(mape[len(mse)-1])

fim = time.time()
time_s = fim - inicio

print('\nTime: {:.2f}'.format(time_s))
print('MSE: {0:.2e}'.format(mse[-1])) 
print('MAE: {0:.2e}'.format(mae[-1]))
print('MAPE: {0:.2e}'.format(mape[-1]))

# %%
# Save results to csv
pd.DataFrame(MAPE).to_csv("MAPE.csv", index=True)
pd.DataFrame(MAE).to_csv("MAE.csv", index=True)
pd.DataFrame(MSE).to_csv("MSE.csv", index=True)

# To load the csv
# x=np.loadtxt('MSE.csv', delimiter=",", dtype=np.float32, skiprows=1)

# %% [markdown]
# # Model evaluation 3: Starndard Seq2Seq LSTM Model

# %%
n_hidden = 100

input_train = Input(shape=(X_input_train.shape[1], X_input_train.shape[2]-1))
output_train = Input(shape=(X_output_train.shape[1], X_output_train.shape[2]-1))

encoder_last_h1, encoder_last_h2, encoder_last_c = LSTM(n_hidden, activation='elu', dropout=0.2, recurrent_dropout=0.2, return_sequences=False, return_state=True)(input_train)
encoder_last_h1 = BatchNormalization(momentum=0.6)(encoder_last_h1)
encoder_last_c = BatchNormalization(momentum=0.6)(encoder_last_c)

decoder = RepeatVector(output_train.shape[1])(encoder_last_h1)
decoder = LSTM(n_hidden, activation='elu', dropout=0.2, recurrent_dropout=0.2, return_state=False, return_sequences=True)(decoder, initial_state=[encoder_last_h1, encoder_last_c])

out = TimeDistributed(Dense(output_train.shape[2]))(decoder)

model = Model(inputs=input_train, outputs=out)
opt = Adam(lr=0.01, clipnorm=1) 
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mse', 'mae', 'mape'])

# Evaluate the time for training the model
inicio = time.time()

# EWT considered
TOTAL = 3

# To save values for statistics
MSE=[]
MAE=[]
MAPE=[]

for i in range(statistics):
  es = EarlyStopping(monitor='val_loss', mode='min', patience=50)
  history = model.fit(X_input_train[:, :, :TOTAL], X_output_train[:, :, :TOTAL], validation_split=0.2, epochs=epc, verbose=1, callbacks=[es], batch_size=batch_siz)
  train_loss = history.history['loss']
  valid_loss = history.history['val_loss']
  mse = history.history['mse']
  mae = history.history['mae']
  mape = history.history['mape']
  model.save('model_forecasting_seq2seq.h5')

  train_pred_detrend = model.predict(X_input_train[:, :, :TOTAL])
  test_pred_detrend = model.predict(X_input_test[:, :, :TOTAL])
  train_true_detrend = X_output_train[:, :, :TOTAL]
  test_true_detrend = X_output_test[:, :, :TOTAL]
  data_final = dict()
  
  print(f'Simulation: {i+1}')
  MSE.append(mse[len(mse)-1])
  MAE.append(mae[len(mse)-1])
  MAPE.append(mape[len(mse)-1])

fim = time.time()
time_s = fim - inicio

print('\nTime: {:.2f}'.format(time_s))
print('MSE: {0:.2e}'.format(mse[-1])) 
print('MAE: {0:.2e}'.format(mae[-1]))
print('MAPE: {0:.2e}'.format(mape[-1]))

# %%
pd.DataFrame(MAPE).to_csv("MAPE_without_at.csv", index=True)
pd.DataFrame(MAE).to_csv("MAE_without_at.csv", index=True)
pd.DataFrame(MSE).to_csv("MSE_without_at.csv", index=True)
